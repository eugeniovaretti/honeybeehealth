# %% [markdown]
# # Check the data correctness

# %% [markdown]
# Comparison and analyses of two different datasets with the same features: TidyTuesday dataset and USDA ones.
# They should contain the same information inside the same datapoints, but it turned out the values were different. <br>
# This notebook aims to understand which dataset has reasonable values that could be considered reliable starting from the knowledge and feature understanding we found in literature.

# %%
from pathlib import Path
import sys
import os

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#pd.__version__

# %%
XSMALL_SIZE = 10
SMALL_SIZE = 12
MEDIUM_SIZE = 15
BIGGER_SIZE = 15

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)     # fontsize of the x and y labels
plt.rc('xtick', labelsize=XSMALL_SIZE)   # fontsize of the tick labels
plt.rc('ytick', labelsize=XSMALL_SIZE)   # fontsize of the tick labels
plt.rc('legend', fontsize=XSMALL_SIZE)   # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

pd.set_option('display.max_rows', None, 'display.max_columns', None)
np.set_printoptions(threshold=sys.maxsize)

# %%
custom_states = sns.color_palette("plasma", 46) #as the number of states
sns.palplot(custom_states)

# %%
color_quarters = sns.color_palette("plasma", 4)
sns.palplot(color_quarters)

# %% [markdown]
# # TidyTuesday dataset of bee colony loss and stressors

# %%
root_path = Path(os.getcwd())
start_path = str(root_path.parent.parent)
df_colony = pd.read_csv(start_path + "/data/colony.csv")
df_stressor = pd.read_csv(start_path + "/data/stressor.csv")

# %%
df_colony.head()
# Out:
#    year         months       state   colony_n  colony_max  colony_lost  \
# 0  2015  January-March     Alabama     7000.0      7000.0       1800.0
# 1  2015  January-March     Arizona    35000.0     35000.0       4600.0
# 2  2015  January-March    Arkansas    13000.0     14000.0       1500.0
# 3  2015  January-March  California  1440000.0   1690000.0     255000.0
# 4  2015  January-March    Colorado     3500.0     12500.0       1500.0
#
#    colony_lost_pct  colony_added  colony_reno  colony_reno_pct
# 0             26.0        2800.0        250.0              4.0
# 1             13.0        3400.0       2100.0              6.0
# 2             11.0        1200.0         90.0              1.0
# 3             15.0      250000.0     124000.0              7.0
# 4             12.0         200.0        140.0              1.0

# %%
#display(df_stressor.to_string())
#print(df_stressor.to_markdown())
df_stressor.head()
# Out:
#    year         months    state               stressor  stress_pct
# 0  2015  January-March  Alabama           Varroa mites        10.0
# 1  2015  January-March  Alabama  Other pests/parasites         5.4
# 2  2015  January-March  Alabama              Disesases         NaN
# 3  2015  January-March  Alabama             Pesticides         2.2
# 4  2015  January-March  Alabama                  Other         9.1

# %%
#map the trimesters into Q1, Q2, Q3, Q4 to guarantee the alphabetical order while grouping
map_quarters = {
    "January-March": "Q1",
    "April-June": "Q2",
    "July-September": "Q3",
    "October-December": "Q4"
}
df_colony['months'] = df_colony['months'].map(map_quarters)
df_stressor['months'] = df_stressor['months'].map(map_quarters)
df_new_stressor = pd.pivot_table(df_stressor, values = 'stress_pct', index = ['year', 'months', 'state'], columns = ['stressor'], sort=False) #fill_value = 0
df_new_stressor.head()
# Out:
# stressor                Varroa mites  Other pests/parasites  Disesases  \
# year months state
# 2015 Q1     Alabama             10.0                    5.4        NaN
#             Arizona             26.9                   20.5        0.1
#             Arkansas            17.6                   11.4        1.5
#             California          24.7                    7.2        3.0
#             Colorado            14.6                    0.9        1.8
#
# stressor                Pesticides  Other  Unknown
# year months state
# 2015 Q1     Alabama            2.2    9.1      9.4
#             Arizona            NaN    1.8      3.1
#             Arkansas           3.4    1.0      1.0
#             California         7.5    6.5      2.8
#             Colorado           0.6    2.6      5.9

# %%
#stressors = df_new_stressor.columns.tolist()

#create MultiIndex in colony dataset
df_colony = df_colony.set_index(['year', 'months', 'state'])
df_colony.head()
#merge the two datasets
dfs = [df_colony, df_new_stressor]
df_years = pd.concat(dfs, axis=1)

#df_years.index.names
#df_years.index.values
#df_years.reset_index()

#add name 'stressor' to stressor columns
#stressor_names = list(map(lambda x: 'Stressor_' + x,list(df_years.columns)[7:]))
#df_years.columns = df_years.columns.tolist()[:7] + stressor_names

df_years.head()
# Out:
#                          colony_n  colony_max  colony_lost  colony_lost_pct  \
# year months state
# 2015 Q1     Alabama        7000.0      7000.0       1800.0             26.0
#             Arizona       35000.0     35000.0       4600.0             13.0
#             Arkansas      13000.0     14000.0       1500.0             11.0
#             California  1440000.0   1690000.0     255000.0             15.0
#             Colorado       3500.0     12500.0       1500.0             12.0
#
#                         colony_added  colony_reno  colony_reno_pct  \
# year months state
# 2015 Q1     Alabama           2800.0        250.0              4.0
#             Arizona           3400.0       2100.0              6.0
#             Arkansas          1200.0         90.0              1.0
#             California      250000.0     124000.0              7.0
#             Colorado           200.0        140.0              1.0
#
#                         Varroa mites  Other pests/parasites  Disesases  \
# year months state
# 2015 Q1     Alabama             10.0                    5.4        NaN
#             Arizona             26.9                   20.5        0.1
#             Arkansas            17.6                   11.4        1.5
#             California          24.7                    7.2        3.0
#             Colorado            14.6                    0.9        1.8
#
#                         Pesticides  Other  Unknown
# year months state
# 2015 Q1     Alabama            2.2    9.1      9.4
#             Arizona            NaN    1.8      3.1
#             Arkansas           3.4    1.0      1.0
#             California         7.5    6.5      2.8
#             Colorado           0.6    2.6      5.9

# %%
#df is the merged dataset without the MultiIndex
df = df_years.reset_index()
df.head()
# Out:
#    year months       state   colony_n  colony_max  colony_lost  \
# 0  2015     Q1     Alabama     7000.0      7000.0       1800.0
# 1  2015     Q1     Arizona    35000.0     35000.0       4600.0
# 2  2015     Q1    Arkansas    13000.0     14000.0       1500.0
# 3  2015     Q1  California  1440000.0   1690000.0     255000.0
# 4  2015     Q1    Colorado     3500.0     12500.0       1500.0
#
#    colony_lost_pct  colony_added  colony_reno  colony_reno_pct  Varroa mites  \
# 0             26.0        2800.0        250.0              4.0          10.0
# 1             13.0        3400.0       2100.0              6.0          26.9
# 2             11.0        1200.0         90.0              1.0          17.6
# 3             15.0      250000.0     124000.0              7.0          24.7
# 4             12.0         200.0        140.0              1.0          14.6
#
#    Other pests/parasites  Disesases  Pesticides  Other  Unknown
# 0                    5.4        NaN         2.2    9.1      9.4
# 1                   20.5        0.1         NaN    1.8      3.1
# 2                   11.4        1.5         3.4    1.0      1.0
# 3                    7.2        3.0         7.5    6.5      2.8
# 4                    0.9        1.8         0.6    2.6      5.9

# %%
#check the number of states
print(len(df.state.unique())) #46 states + "United States"
print(df.shape) #(1380, 16)
# Out:
# 47
# (1410, 16)

# %%
#Extract United States dataset
#df_US = df.loc[(slice(None), slice(None), 'United States'),:]
df_US = df[df.state == 'United States']
df_US.drop(columns = ["state"], inplace=True)
df_years.drop(index = "United States", level=2, inplace=True)
df = df[df.state != 'United States']
df_US.head()
#df.index.tolist()
# Out:
#      year months   colony_n  colony_max  colony_lost  colony_lost_pct  \
# 46   2015     Q1  2824610.0         NaN     500020.0             18.0
# 93   2015     Q2  2849500.0         NaN     352860.0             12.0
# 140  2015     Q3  3132880.0         NaN     457100.0             15.0
# 187  2015     Q4  2874760.0         NaN     412380.0             14.0
# 234  2016     Q1  2594590.0         NaN     428800.0             17.0
#
#      colony_added  colony_reno  colony_reno_pct  Varroa mites  \
# 46       546980.0     270530.0             10.0          25.2
# 93       661860.0     692850.0             24.0          43.4
# 140      172990.0     303070.0             10.0          41.2
# 187      117150.0     158790.0              6.0          37.0
# 234      378160.0     158050.0              6.0          34.3
#
#      Other pests/parasites  Disesases  Pesticides  Other  Unknown
# 46                     8.6        3.1         7.4    6.9      4.3
# 93                    19.5        4.9        16.6   11.6      3.5
# 140                   17.6        8.0        15.2    8.8      4.8
# 187                   11.4        5.2         9.5    7.3      6.9
# 234                   12.6        6.2        10.5    7.0      5.4

# %% [markdown]
# ## Check the understanding of features and their interpretation

# %% [markdown]
# From literature: <br>
# - **Added colonies**: A new or replacement, surviving colony that was either created or purchased whole by an operation.
# - **Colony**: A hive containing a queen honey bee and attendant worker bees and/or drone bees.
# - **Lost colony**: A completely failed colony, loss of most workers, and possibly the queen. Colony is no longer viable. Sometimes referred to as a dead out.
#
# - **Maximum colonies**: Refers to the sum of colonies in a state on the first of the quarter plus all those moved into the state during that period. Maximum colonies is considered the base number from which a data user can do further analysis. It does not include the colonies that were added, lost, or renovated in the state. Colonies are counted in every state they were in during the quarter; therefore, a national level maximum number of colonies cannot be calculated due to duplication.
# - **Percent lost**: The state-level percentage of colonies lost is the number of colonies lost in that state divided by the maximum colonies for that state. The national level percentage of colonies lost is the total number of all colonies lost in the United States divided by the number of colonies on the first of the quarter.
# - **Percent renovated**: The state-level percentage of colonies renovated is the number of colonies renovated in that state divided by the maximum colonies for that state. The national level percentage of colonies renovated is the total number of all colonies renovated in the United States divided by the number of colonies on the first of the quarter.
# - **Renovated colony**: An existing colony that was requeened or received a nuc or package.
# - **Stressors**: State level colony health stressors for operations with five or more colonies are the percent of the maximum colonies reported to be affected, by quarter. The national level colony stressors is the summed number for the United States divided by the number of colonies on the first of the quarter.

# %% [markdown]
# ## US Data

# %%
df_US2 = df_US[["year", "months", "colony_n", "colony_lost", "colony_added", "colony_reno"]]
df_US2["colony_end"] = df_US2["colony_n"].shift(-1)
df_US2["colony_end_computed"] = df_US2["colony_n"] + df_US2["colony_added"] - df_US2["colony_lost"]
df_US2["diff_without_reno"] = df_US2["colony_end_computed"]-df_US2["colony_end"]
df_US2["diff_without_reno_pct"] = df_US2["diff_without_reno"]*100/df_US2["colony_end"]
#df_US2["diff_with_reno"] = df_US2["diff_without_reno"] + df_US2["colony_reno"]

print(df_US2.shape)
df_US2.head()
# Out:
# (30, 10)
#      year months   colony_n  colony_lost  colony_added  colony_reno  \
# 46   2015     Q1  2824610.0     500020.0      546980.0     270530.0
# 93   2015     Q2  2849500.0     352860.0      661860.0     692850.0
# 140  2015     Q3  3132880.0     457100.0      172990.0     303070.0
# 187  2015     Q4  2874760.0     412380.0      117150.0     158790.0
# 234  2016     Q1  2594590.0     428800.0      378160.0     158050.0
#
#      colony_end  colony_end_computed  diff_without_reno  diff_without_reno_pct
# 46    2849500.0            2871570.0            22070.0               0.774522
# 93    3132880.0            3158500.0            25620.0               0.817778
# 140   2874760.0            2848770.0           -25990.0              -0.904075
# 187   2594590.0            2579530.0           -15060.0              -0.580439
# 234   2801470.0            2543950.0          -257520.0              -9.192317

# %% [markdown]
# Note that we cannot assess the calculations for 2019 - Q1 and 2019 - Q2 because all the datapoints for 2019 - Q2 are missing.

# %%
from matplotlib.ticker import MultipleLocator 

fig, ax = plt.subplots(figsize=(16,15))
plt.title('US data: differences between computed colonies at the end of the quarter and beginning inventory of next quarter')
plt.ylabel('Difference values (%)')
df_US2.groupby(["year", "months"]).sum()["diff_without_reno_pct"].plot(ax=ax, marker="o",color=custom_states)
plt.axhline(y=0, color='r', linestyle='-')
plt.ylim([-10,+11])
ax.xaxis.set_major_locator(MultipleLocator(1))
#plt.xticks(df_US3.groupby(["year", "months"]).sum().index.tolist())

plt.show()

# %% [markdown]
# The interpretation and connection through features that was explained above cannot retrieve in these US data since there are relevant difference around +/- 10%, while we would expect at most a +/- 2% due to the inaccuracy of bee keepers while filling the surveys where the data were extracted from.

# %% [markdown]
# ## Understand the computation of n colonies along the quarters for each state

# %%
#all the datapoints in 2019-Q2 are missing --> the respected rows are removed
df_years.dropna(axis=0, how="all", inplace=True)
# Fill missing values for colony-related features (not stressors)
df_years[["colony_added", "colony_reno"]] = df_years[["colony_added", "colony_reno"]].fillna(value = 0, inplace=False)


#Note: to get the indices of NaN values for a given column:
#df_years[df_years['name_column'].isnull()].index.tolist()

# %%
#at time t: n_colony(t) = max_colony(t-1)+colony_added(t-1)- colony_lost(t-1)

#df_states = df_years.reorder_levels(["state", "year", "months"]).sort_index()
df_states = df_years.reset_index().groupby(["state", "year", "months"]).sum()
df_states.head(50)

df_states["colony_end"] = df_states["colony_n"].shift(-1) #number of colonies at the beginning of next trimester
#number of colonies we would expect to have at the end of the trimester:
df_states["colony_end_computed"] = df_states["colony_max"] + df_states["colony_added"] - df_states["colony_lost"]
df_states["differences"] = df_states["colony_end_computed"] - df_states["colony_end"] #differences between expected
#number of colonies and real number at the end of the trimester
df_states["problem_check"] = df_states["differences"] + df_states["colony_reno"]

#the differences which is encoded in "differences" are critical when they are < 0. Indeed, if our data knowledge is
#correct, we would expect to have "colony_end_computed" > "colony_end" since there are no information of the colonies
#that left the state during the trimester.
#If this is not the case (i.e. "differences" < 0), it means that there are some issues in our understanding
#of datapoints and how we are trying to link them along the trimesters.
pd.Series(df_states["differences"] < 0).value_counts()
#df_states.head(50)

#Note that "differences" does not account for "colony_repo" (as if these were not colony added during the trimester),
#while "problem_check" accounts for "colony_repo"
# Out:
# False    922
# True     412
# Name: differences, dtype: int64

# %%
#df_states.index.values
#print(df_states.loc[("Alabama", 2019, ["Q1", "Q3", "Q4"]), :])

#Let's set "differences" and "problem_check" equal to 0 in 2019-Q1 since the values for 2019-Q2 are missing so
#these two features cannot be properly computed
df_states.loc[(slice(None), 2019, "Q1"),["differences", "problem_check"]] = 0

#Let's also set "differences" and "problem_check" equal to 0 in 2022-Q2 since these values compare
#"colony_end_computed" with "colony_end" at 2015-Q1 of another state --> this does not have sense
df_states.loc[(slice(None), 2022, "Q2"),["differences", "problem_check"]] = 0

# %%
#Let's check when "problem_check" has negative values
df_states[df_states.problem_check < 0]
# Out:
#                             colony_n  colony_max  colony_lost  \
# state          year months
# Alabama        2016 Q1        7500.0      7500.0       1700.0
#                     Q4        7000.0      7000.0        610.0
# Arizona        2020 Q1       29000.0     32000.0       6500.0
#                2021 Q1       29000.0     29000.0       7000.0
#                2022 Q1       25000.0     28000.0       2300.0
# Arkansas       2015 Q3       23000.0     30000.0       9000.0
#                     Q4       23000.0     27000.0       2400.0
#                2017 Q2       17000.0     17000.0       1900.0
#                     Q4       25000.0     25000.0       7500.0
#                2018 Q2       11500.0     11500.0       1500.0
#                     Q4       30000.0     31000.0       6000.0
# Colorado       2015 Q1        3500.0     12500.0       1500.0
#                2016 Q1        6000.0      7000.0        570.0
#                2021 Q1        3000.0     16500.0        640.0
#                2022 Q1        3800.0      8500.0        540.0
# Connecticut    2016 Q2        2500.0      2500.0        100.0
#                     Q4        3100.0      3100.0        240.0
#                2017 Q1        3100.0      3100.0        380.0
#                     Q3        3500.0      3500.0        130.0
#                2018 Q1        2900.0      2900.0        140.0
#                     Q3        3200.0      3200.0        130.0
#                2020 Q1        3700.0      4100.0        330.0
#                     Q4        4300.0      4600.0        500.0
# Georgia        2016 Q4       96000.0    112000.0      11000.0
#                2017 Q4      125000.0    145000.0      21000.0
# Hawaii         2017 Q2       12000.0     12000.0         60.0
#                     Q3       15000.0     15000.0       1100.0
#                2020 Q2       15500.0     15500.0         40.0
# Illinois       2015 Q1        6000.0     10500.0       4200.0
#                2016 Q1        7000.0      7500.0       1300.0
#                     Q2        9000.0      9000.0        740.0
#                     Q4        9000.0      9000.0        720.0
#                2017 Q1       11000.0     11000.0       2900.0
#                2018 Q1       10500.0     10500.0       2400.0
#                     Q3       11000.0     11000.0        660.0
#                2020 Q1       11500.0     13000.0       2100.0
# Indiana        2016 Q4        7500.0      7500.0       1200.0
#                2017 Q1        7000.0      7500.0       1900.0
#                2018 Q1        7000.0      8000.0       1000.0
#                2021 Q1       10000.0     11000.0       2700.0
# Iowa           2018 Q1       41000.0     45000.0       1300.0
#                2021 Q3       37000.0     54000.0       4500.0
#                2022 Q1       26000.0     29000.0       2800.0
# Kansas         2015 Q1        4600.0      7000.0       1600.0
#                2016 Q1        4700.0      4700.0        980.0
#                2017 Q1        3800.0      3800.0       1000.0
#                2018 Q1        3700.0      3700.0        950.0
#                2021 Q1        5000.0      6500.0       1400.0
# Kentucky       2015 Q1        7500.0     10500.0       4100.0
#                2018 Q1        5500.0      5500.0       1600.0
#                2020 Q1        7000.0     10500.0       1200.0
#                2021 Q1        9500.0      9500.0       2100.0
# Louisiana      2019 Q4       41000.0     46000.0       2300.0
#                2020 Q4       46000.0     52000.0       1700.0
# Maine          2016 Q1        2200.0      3700.0        170.0
#                2018 Q1        1900.0      1900.0        240.0
#                     Q3       12500.0     12500.0        890.0
#                2020 Q1        1300.0      1700.0        130.0
# Maryland       2016 Q1        6500.0      6500.0       1400.0
#                     Q3        7000.0      7000.0        200.0
#                2017 Q1        9000.0      9000.0       2100.0
#                2018 Q1        8000.0      8000.0       1500.0
#                2020 Q1        7000.0      7500.0        640.0
#                2021 Q4        5500.0      6000.0        720.0
# Massachusetts  2015 Q1        2900.0      4600.0       1000.0
#                2016 Q1        3000.0      3000.0        370.0
#                2018 Q1        3800.0      3800.0       1000.0
#                2021 Q2        4000.0     10000.0        810.0
# Michigan       2016 Q1       25000.0     37000.0       5000.0
#                2017 Q1       29000.0     59000.0       5000.0
#                2020 Q1       60000.0     65000.0       6000.0
#                     Q2       64000.0     79000.0       2600.0
#                2021 Q2       75000.0     97000.0       3500.0
# Minnesota      2020 Q1       21000.0     57000.0       1000.0
#                2021 Q1       41000.0     68000.0       3200.0
#                     Q4      100000.0    100000.0      10500.0
# Mississippi    2015 Q3       23000.0     34000.0       3500.0
#                2016 Q1       24000.0     77000.0       6500.0
#                     Q4       17500.0     30000.0       2400.0
#                2018 Q3       16500.0     16500.0       2900.0
#                     Q4       14500.0     25000.0       2000.0
# Missouri       2016 Q1       11500.0     11500.0       1200.0
#                2017 Q1        6500.0      7500.0       1200.0
#                     Q3        9000.0      9000.0        580.0
#                2018 Q2        7000.0      7000.0        390.0
#                2020 Q1        8500.0      8500.0       2100.0
# Montana        2016 Q1       15500.0     48000.0        840.0
#                2020 Q1       18000.0     48000.0        150.0
# Nebraska       2015 Q1       10000.0     31000.0       2600.0
#                2018 Q2       10500.0     40000.0       2700.0
#                2020 Q1        9000.0     17000.0        670.0
#                     Q2       16500.0     39000.0       1800.0
#                2021 Q1       11000.0     17500.0        640.0
#                     Q2       18500.0     37000.0       1800.0
# New Jersey     2015 Q4        8000.0      8500.0        270.0
#                2018 Q3       14000.0     14000.0        320.0
#                2020 Q1        6500.0      7000.0        250.0
#                2021 Q1       14000.0     14000.0        360.0
#                2022 Q1       15000.0     15000.0        550.0
# New Mexico     2016 Q1        6000.0      6500.0       1700.0
#                2018 Q2        1900.0      4300.0         50.0
#                2019 Q4        6000.0      6000.0         70.0
#                2021 Q1        3500.0      3500.0        230.0
# New York       2016 Q1       31000.0     31000.0       4000.0
#                2018 Q2       20000.0     36000.0       3300.0
#                2020 Q1       29000.0     36000.0       3700.0
#                     Q2       33000.0     56000.0       4900.0
#                2021 Q1       30000.0     30000.0       4900.0
# North Carolina 2016 Q1       18500.0     24000.0       2500.0
#                2017 Q4       23000.0     23000.0       5000.0
#                2021 Q1       18000.0     21000.0       2100.0
# North Dakota   2017 Q2      112000.0    385000.0      10500.0
#                2020 Q2       67000.0    395000.0      17500.0
#                2021 Q2       42000.0    395000.0       4400.0
#                2022 Q1       75000.0     89000.0        120.0
# Ohio           2016 Q1       16000.0     16000.0       4200.0
#                2018 Q1       12000.0     14000.0       4000.0
# Oklahoma       2015 Q1        9500.0     26000.0       6000.0
#                2016 Q1        6000.0      6000.0       2900.0
#                2018 Q1       17000.0     18000.0       3700.0
#                     Q3        2100.0      2100.0        370.0
#                2020 Q4        7000.0     28000.0        300.0
# Oregon         2021 Q1       76000.0     79000.0       3100.0
#                     Q2       80000.0     84000.0       3300.0
#                2022 Q1       92000.0     95000.0       5000.0
# Other States   2015 Q1        3410.0      8990.0       2080.0
#                2016 Q1        7290.0      7890.0        900.0
#                     Q4        6360.0      6460.0        580.0
#                2017 Q1        6190.0      6490.0       1540.0
#                2020 Q2        6500.0      7440.0        250.0
# Pennsylvania   2015 Q1       14000.0     21000.0       6500.0
#                2016 Q1       12500.0     12500.0       2900.0
#                2018 Q1       14500.0     14500.0       1500.0
#                2021 Q1       20000.0     21000.0       5500.0
# South Carolina 2016 Q4       12000.0     17000.0       1300.0
#                2021 Q1       15500.0     18500.0       1200.0
# South Dakota   2020 Q2        9500.0    205000.0       4600.0
# Tennessee      2016 Q1        9000.0      9000.0       1700.0
#                     Q4        9000.0      9000.0        840.0
#                2017 Q4        8500.0     10500.0       1300.0
# Texas          2018 Q4      116000.0    260000.0      17000.0
#                2019 Q4      129000.0    240000.0      17500.0
# Utah           2015 Q1        6000.0     24000.0       3300.0
#                2016 Q1       12000.0     12500.0       1700.0
#                2017 Q1       16000.0     18500.0       2700.0
#                2020 Q1       12000.0     17000.0        400.0
# Vermont        2016 Q3        6500.0      6500.0        400.0
#                     Q4        6500.0      6500.0        260.0
#                2018 Q1        5500.0      5500.0        570.0
#                     Q4        6500.0      6500.0        170.0
#                2021 Q1        7500.0      7500.0       1300.0
# Virginia       2016 Q4        7000.0      7000.0        730.0
#                2021 Q1        7000.0      7000.0       1400.0
# West Virginia  2016 Q1        6500.0      7500.0       1700.0
#                2018 Q1        4700.0      8500.0       2000.0
# Wisconsin      2020 Q1       16000.0     26000.0       1500.0
#                     Q2       27000.0     53000.0       1700.0
#                2021 Q1       25000.0     37000.0       2500.0
#                2022 Q1       39000.0     53000.0       2800.0
# Wyoming        2016 Q1        2700.0      5000.0        340.0
#                2017 Q1        6500.0     17000.0       3600.0
#                2018 Q1        5500.0      8000.0        220.0
#                     Q2        8500.0     22000.0       2200.0
#                2020 Q1        4000.0     17000.0        140.0
#                     Q2       17500.0     24000.0       1600.0
#                2022 Q1        6000.0      8000.0        180.0
#
#                             colony_lost_pct  colony_added  colony_reno  \
# state          year months
# Alabama        2016 Q1                 23.0        1200.0        180.0
#                     Q4                  9.0          50.0         10.0
# Arizona        2020 Q1                 20.0         150.0        120.0
#                2021 Q1                 24.0        3500.0        180.0
#                2022 Q1                  8.0        4700.0         10.0
# Arkansas       2015 Q3                 30.0         500.0        210.0
#                     Q4                  9.0        1900.0          0.0
#                2017 Q2                 11.0        5000.0       1300.0
#                     Q4                 30.0        2500.0        440.0
#                2018 Q2                 13.0       14000.0       1900.0
#                     Q4                 19.0         110.0        230.0
# Colorado       2015 Q1                 12.0         200.0        140.0
#                2016 Q1                  8.0           0.0         20.0
#                2021 Q1                  4.0         850.0         30.0
#                2022 Q1                  6.0           0.0         10.0
# Connecticut    2016 Q2                  4.0         390.0         60.0
#                     Q4                  8.0           0.0          0.0
#                2017 Q1                 12.0         100.0        110.0
#                     Q3                  4.0          50.0         20.0
#                2018 Q1                  5.0         220.0        330.0
#                     Q3                  4.0          80.0        310.0
#                2020 Q1                  8.0          60.0          0.0
#                     Q4                 11.0          20.0         20.0
# Georgia        2016 Q4                 10.0       12000.0        450.0
#                2017 Q4                 14.0        4300.0       2200.0
# Hawaii         2017 Q2                  1.0         520.0        910.0
#                     Q3                  7.0         430.0         20.0
#                2020 Q2                  0.0         240.0       2300.0
# Illinois       2015 Q1                 40.0        2300.0        390.0
#                2016 Q1                 17.0         470.0         20.0
#                     Q2                  8.0        2200.0        380.0
#                     Q4                  8.0           0.0          0.0
#                2017 Q1                 26.0        3100.0        150.0
#                2018 Q1                 23.0        1000.0        630.0
#                     Q3                  6.0         700.0        420.0
#                2020 Q1                 16.0         900.0        160.0
# Indiana        2016 Q4                 16.0          20.0          0.0
#                2017 Q1                 25.0        1700.0         70.0
#                2018 Q1                 13.0         300.0         30.0
#                2021 Q1                 25.0        3500.0         20.0
# Iowa           2018 Q1                  3.0         420.0        110.0
#                2021 Q3                  8.0        1000.0        130.0
#                2022 Q1                 10.0         610.0         30.0
# Kansas         2015 Q1                 23.0         450.0         70.0
#                2016 Q1                 21.0           0.0        200.0
#                2017 Q1                 26.0         930.0        380.0
#                2018 Q1                 26.0         500.0        410.0
#                2021 Q1                 22.0        2300.0         10.0
# Kentucky       2015 Q1                 39.0         250.0          0.0
#                2018 Q1                 29.0         520.0         20.0
#                2020 Q1                 11.0        1500.0        120.0
#                2021 Q1                 22.0        2500.0         80.0
# Louisiana      2019 Q4                  5.0          70.0         80.0
#                2020 Q4                  3.0          30.0        620.0
# Maine          2016 Q1                  5.0           0.0          0.0
#                2018 Q1                 13.0          40.0         30.0
#                     Q3                  7.0          60.0        170.0
#                2020 Q1                  8.0           0.0          0.0
# Maryland       2016 Q1                 22.0          40.0         20.0
#                     Q3                  3.0         400.0         20.0
#                2017 Q1                 23.0         770.0        260.0
#                2018 Q1                 19.0           0.0        190.0
#                2020 Q1                  9.0           0.0         30.0
#                2021 Q4                 12.0        1200.0          0.0
# Massachusetts  2015 Q1                 22.0         260.0        120.0
#                2016 Q1                 12.0         120.0        330.0
#                2018 Q1                 26.0         240.0        290.0
#                2021 Q2                  8.0        1400.0        310.0
# Michigan       2016 Q1                 14.0        2300.0        110.0
#                2017 Q1                  8.0         600.0        130.0
#                2020 Q1                  9.0        3800.0        100.0
#                     Q2                  3.0        9500.0      10000.0
#                2021 Q2                  4.0       10000.0       8000.0
# Minnesota      2020 Q1                  2.0        2000.0         40.0
#                2021 Q1                  5.0        2900.0        140.0
#                     Q4                 11.0        4900.0        350.0
# Mississippi    2015 Q3                 10.0         260.0        110.0
#                2016 Q1                  8.0       11000.0       1700.0
#                     Q4                  8.0         330.0         60.0
#                2018 Q3                 18.0         110.0        650.0
#                     Q4                  8.0         330.0         50.0
# Missouri       2016 Q1                 10.0         930.0        290.0
#                2017 Q1                 16.0         400.0         10.0
#                     Q3                  6.0         320.0        310.0
#                2018 Q2                  6.0        1800.0        800.0
#                2020 Q1                 25.0          30.0          0.0
# Montana        2016 Q1                  2.0       11500.0          0.0
#                2020 Q1                  0.0           0.0          0.0
# Nebraska       2015 Q1                  8.0         120.0        310.0
#                2018 Q2                  7.0        3100.0        700.0
#                2020 Q1                  4.0          70.0          0.0
#                     Q2                  5.0        7000.0       1100.0
#                2021 Q1                  4.0        1300.0          0.0
#                     Q2                  5.0        8500.0        810.0
# New Jersey     2015 Q4                  3.0          20.0         10.0
#                2018 Q3                  2.0         250.0        220.0
#                2020 Q1                  4.0         110.0         40.0
#                2021 Q1                  3.0         610.0         80.0
#                2022 Q1                  4.0        1500.0         30.0
# New Mexico     2016 Q1                 26.0          10.0         70.0
#                2018 Q2                  1.0         290.0        450.0
#                2019 Q4                  1.0          30.0         10.0
#                2021 Q1                  7.0        2200.0          0.0
# New York       2016 Q1                 13.0         140.0       1400.0
#                2018 Q2                  9.0        8000.0       2300.0
#                2020 Q1                 10.0         230.0        370.0
#                     Q2                  9.0        6500.0       3300.0
#                2021 Q1                 16.0        3400.0        380.0
# North Carolina 2016 Q1                 10.0          80.0        840.0
#                2017 Q4                 22.0          60.0        290.0
#                2021 Q1                 10.0        2700.0        110.0
# North Dakota   2017 Q2                  3.0       19500.0      37000.0
#                2020 Q2                  4.0       29000.0      37000.0
#                2021 Q2                  1.0        4800.0       3500.0
#                2022 Q1                  0.0         300.0          0.0
# Ohio           2016 Q1                 26.0         760.0        100.0
#                2018 Q1                 29.0         300.0        580.0
# Oklahoma       2015 Q1                 23.0        2600.0        260.0
#                2016 Q1                 48.0          60.0        510.0
#                2018 Q1                 21.0         890.0        240.0
#                     Q3                 18.0          20.0         10.0
#                2020 Q4                  1.0         250.0          0.0
# Oregon         2021 Q1                  4.0        2600.0        610.0
#                     Q2                  4.0       25000.0      19500.0
#                2022 Q1                  5.0        2400.0        310.0
# Other States   2015 Q1                 23.0         870.0        150.0
#                2016 Q1                 11.0          60.0         10.0
#                     Q4                  9.0          20.0          0.0
#                2017 Q1                 24.0         130.0         50.0
#                2020 Q2                  3.0        1270.0       1500.0
# Pennsylvania   2015 Q1                 31.0         360.0          0.0
#                2016 Q1                 23.0         220.0        340.0
#                2018 Q1                 10.0        1600.0        670.0
#                2021 Q1                 26.0        4100.0         40.0
# South Carolina 2016 Q4                  8.0         760.0        370.0
#                2021 Q1                  6.0         930.0        190.0
# South Dakota   2020 Q2                  2.0        8500.0      14500.0
# Tennessee      2016 Q1                 19.0         100.0        150.0
#                     Q4                  9.0         120.0         10.0
#                2017 Q4                 12.0         230.0        320.0
# Texas          2018 Q4                  7.0       11000.0         70.0
#                2019 Q4                  7.0        8000.0       1700.0
# Utah           2015 Q1                 14.0        2500.0        290.0
#                2016 Q1                 14.0         710.0        100.0
#                2017 Q1                 15.0        2900.0         60.0
#                2020 Q1                  2.0        4200.0          0.0
# Vermont        2016 Q3                  6.0         170.0         50.0
#                     Q4                  4.0          20.0         10.0
#                2018 Q1                 10.0          20.0          0.0
#                     Q4                  3.0          10.0         20.0
#                2021 Q1                 17.0         670.0         70.0
# Virginia       2016 Q4                 10.0         230.0         10.0
#                2021 Q1                 20.0        2300.0         50.0
# West Virginia  2016 Q1                 23.0           0.0         10.0
#                2018 Q1                 24.0         330.0         60.0
# Wisconsin      2020 Q1                  6.0        2000.0        370.0
#                     Q2                  3.0       11500.0       4600.0
#                2021 Q1                  7.0        7000.0        170.0
#                2022 Q1                  5.0        1400.0        240.0
# Wyoming        2016 Q1                  7.0           0.0          0.0
#                2017 Q1                 21.0        1300.0          0.0
#                2018 Q1                  3.0          70.0          0.0
#                     Q2                 10.0        3100.0       2300.0
#                2020 Q1                  1.0         450.0         60.0
#                     Q2                  7.0        2300.0       2100.0
#                2022 Q1                  2.0          20.0          0.0
#
#                             colony_reno_pct  Varroa mites  \
# state          year months
# Alabama        2016 Q1                  2.0          24.2
#                     Q4                  0.0          12.3
# Arizona        2020 Q1                  0.0          31.7
#                2021 Q1                  1.0           4.6
#                2022 Q1                  0.0          14.8
# Arkansas       2015 Q3                  1.0          69.2
#                     Q4                  0.0          38.1
#                2017 Q2                  8.0          24.5
#                     Q4                  2.0          37.5
#                2018 Q2                 17.0          35.5
#                     Q4                  1.0          82.8
# Colorado       2015 Q1                  1.0          14.6
#                2016 Q1                  0.0           3.5
#                2021 Q1                  0.0           2.1
#                2022 Q1                  0.0           4.0
# Connecticut    2016 Q2                  2.0           9.3
#                     Q4                  0.0          14.7
#                2017 Q1                  4.0          51.5
#                     Q3                  1.0          25.1
#                2018 Q1                 11.0          14.5
#                     Q3                 10.0          13.0
#                2020 Q1                  0.0          11.2
#                     Q4                  0.0          49.4
# Georgia        2016 Q4                  0.0          43.6
#                2017 Q4                  2.0          56.8
# Hawaii         2017 Q2                  8.0          89.5
#                     Q3                  0.0           2.8
#                2020 Q2                 15.0          43.1
# Illinois       2015 Q1                  4.0          12.3
#                2016 Q1                  0.0          15.0
#                     Q2                  4.0          11.4
#                     Q4                  0.0          27.8
#                2017 Q1                  1.0          24.3
#                2018 Q1                  6.0          25.7
#                     Q3                  4.0          21.2
#                2020 Q1                  1.0          17.2
# Indiana        2016 Q4                  0.0          28.2
#                2017 Q1                  1.0          15.8
#                2018 Q1                  0.0          33.4
#                2021 Q1                  0.0          34.4
# Iowa           2018 Q1                  0.0           5.3
#                2021 Q3                  0.0           7.5
#                2022 Q1                  0.0          29.7
# Kansas         2015 Q1                  1.0          32.7
#                2016 Q1                  4.0          32.2
#                2017 Q1                 10.0          47.1
#                2018 Q1                 11.0          63.0
#                2021 Q1                  0.0          25.7
# Kentucky       2015 Q1                  0.0          10.8
#                2018 Q1                  0.0          43.0
#                2020 Q1                  1.0          17.4
#                2021 Q1                  1.0          27.5
# Louisiana      2019 Q4                  0.0          33.0
#                2020 Q4                  1.0          22.2
# Maine          2016 Q1                  0.0           3.3
#                2018 Q1                  2.0          23.6
#                     Q3                  1.0          37.0
#                2020 Q1                  0.0          19.6
# Maryland       2016 Q1                  0.0          30.2
#                     Q3                  0.0          10.8
#                2017 Q1                  3.0          11.3
#                2018 Q1                  2.0          18.2
#                2020 Q1                  0.0          19.9
#                2021 Q4                  0.0          21.2
# Massachusetts  2015 Q1                  3.0          23.5
#                2016 Q1                 11.0          10.1
#                2018 Q1                  8.0          19.1
#                2021 Q2                  3.0          45.5
# Michigan       2016 Q1                  0.0           5.4
#                2017 Q1                  0.0           7.9
#                2020 Q1                  0.0           8.1
#                     Q2                 13.0          38.0
#                2021 Q2                  8.0          45.1
# Minnesota      2020 Q1                  0.0           3.5
#                2021 Q1                  0.0           6.3
#                     Q4                  0.0           8.0
# Mississippi    2015 Q3                  0.0          45.5
#                2016 Q1                  2.0           8.5
#                     Q4                  0.0          21.9
#                2018 Q3                  4.0          25.2
#                     Q4                  0.0          26.5
# Missouri       2016 Q1                  3.0          17.8
#                2017 Q1                  0.0          16.2
#                     Q3                  3.0          77.7
#                2018 Q2                 11.0          11.8
#                2020 Q1                  0.0           8.4
# Montana        2016 Q1                  0.0           0.8
#                2020 Q1                  0.0           4.0
# Nebraska       2015 Q1                  1.0           5.9
#                2018 Q2                  2.0           3.9
#                2020 Q1                  0.0           2.2
#                     Q2                  3.0          15.8
#                2021 Q1                  0.0           0.0
#                     Q2                  2.0          17.4
# New Jersey     2015 Q4                  0.0           7.7
#                2018 Q3                  2.0          12.3
#                2020 Q1                  1.0           9.4
#                2021 Q1                  1.0          18.7
#                2022 Q1                  0.0          13.3
# New Mexico     2016 Q1                  1.0          69.0
#                2018 Q2                 10.0           0.3
#                2019 Q4                  0.0           5.2
#                2021 Q1                  0.0          14.2
# New York       2016 Q1                  5.0          27.5
#                2018 Q2                  6.0          40.8
#                2020 Q1                  1.0           6.6
#                     Q2                  6.0          21.2
#                2021 Q1                  1.0          15.0
# North Carolina 2016 Q1                  4.0           9.6
#                2017 Q4                  1.0          64.2
#                2021 Q1                  1.0          23.7
# North Dakota   2017 Q2                 10.0          27.9
#                2020 Q2                  9.0          25.7
#                2021 Q2                  1.0          29.9
#                2022 Q1                  0.0          33.1
# Ohio           2016 Q1                  1.0          41.9
#                2018 Q1                  4.0          39.6
# Oklahoma       2015 Q1                  1.0          14.5
#                2016 Q1                  9.0           9.7
#                2018 Q1                  1.0          24.1
#                     Q3                  0.0          59.6
#                2020 Q4                  0.0           2.3
# Oregon         2021 Q1                  1.0          12.9
#                     Q2                 23.0          17.2
#                2022 Q1                  0.0          11.4
# Other States   2015 Q1                  2.0           0.8
#                2016 Q1                  0.0           0.1
#                     Q4                  0.0          24.1
#                2017 Q1                  1.0           3.4
#                2020 Q2                 20.0          16.8
# Pennsylvania   2015 Q1                  0.0          28.1
#                2016 Q1                  3.0          44.8
#                2018 Q1                  5.0          34.4
#                2021 Q1                  0.0          18.1
# South Carolina 2016 Q4                  2.0          29.0
#                2021 Q1                  1.0          48.5
# South Dakota   2020 Q2                  7.0          53.4
# Tennessee      2016 Q1                  2.0          19.7
#                     Q4                  0.0          19.9
#                2017 Q4                  3.0          22.8
# Texas          2018 Q4                  0.0          18.6
#                2019 Q4                  1.0          23.1
# Utah           2015 Q1                  1.0          13.6
#                2016 Q1                  1.0          28.8
#                2017 Q1                  0.0          38.7
#                2020 Q1                  0.0          38.9
# Vermont        2016 Q3                  1.0           5.6
#                     Q4                  0.0          44.5
#                2018 Q1                  0.0          17.0
#                     Q4                  0.0           6.2
#                2021 Q1                  1.0          21.1
# Virginia       2016 Q4                  0.0          31.4
#                2021 Q1                  1.0          11.9
# West Virginia  2016 Q1                  0.0          21.9
#                2018 Q1                  1.0          15.0
# Wisconsin      2020 Q1                  1.0           9.0
#                     Q2                  9.0          46.1
#                2021 Q1                  0.0          16.1
#                2022 Q1                  0.0           7.9
# Wyoming        2016 Q1                  0.0           0.0
#                2017 Q1                  0.0           0.2
#                2018 Q1                  0.0           0.9
#                     Q2                 10.0          11.0
#                2020 Q1                  0.0           0.2
#                     Q2                  9.0          28.8
#                2022 Q1                  0.0           1.3
#
#                             Other pests/parasites  Disesases  Pesticides  \
# state          year months
# Alabama        2016 Q1                       22.0        4.3         8.1
#                     Q4                        9.9        0.2         2.4
# Arizona        2020 Q1                        0.1        0.1         0.0
#                2021 Q1                        5.9        5.9         0.0
#                2022 Q1                        0.0        3.0         0.0
# Arkansas       2015 Q3                       32.4        0.9         5.0
#                     Q4                        9.7        0.1         8.2
#                2017 Q2                       12.2        2.4         4.9
#                     Q4                       29.2       26.6        31.0
#                2018 Q2                       16.0        0.9         2.8
#                     Q4                        7.1        0.0        73.5
# Colorado       2015 Q1                        0.9        1.8         0.6
#                2016 Q1                        4.7        0.6         0.3
#                2021 Q1                        0.0        0.0         0.0
#                2022 Q1                        0.0        3.8         0.6
# Connecticut    2016 Q2                        0.6        0.5         0.3
#                     Q4                        6.6        1.1         1.0
#                2017 Q1                        1.5        0.0         0.0
#                     Q3                        1.5        0.1         0.0
#                2018 Q1                        0.7        0.0         0.8
#                     Q3                        0.0        0.0         1.4
#                2020 Q1                        2.9        0.4         0.0
#                     Q4                        0.9        0.1         0.0
# Georgia        2016 Q4                        8.6        3.7         7.6
#                2017 Q4                       15.1       12.3        15.3
# Hawaii         2017 Q2                        3.5        0.0         0.0
#                     Q3                        4.3        0.3         0.0
#                2020 Q2                       41.1        1.0         0.0
# Illinois       2015 Q1                        6.9        0.7         0.4
#                2016 Q1                        7.8        0.4         2.9
#                     Q2                        4.4        2.0         3.1
#                     Q4                       11.7        1.2         5.6
#                2017 Q1                       11.8        0.6         4.2
#                2018 Q1                       11.2        3.6         3.5
#                     Q3                       10.6        2.1         5.1
#                2020 Q1                        8.9        0.2         0.0
# Indiana        2016 Q4                        9.6        0.2         1.4
#                2017 Q1                        8.0        5.2         4.1
#                2018 Q1                        8.3        3.0         0.5
#                2021 Q1                        5.4        0.0         0.7
# Iowa           2018 Q1                        1.1        0.3         0.6
#                2021 Q3                        1.6        2.8         5.9
#                2022 Q1                       13.0        0.7         0.9
# Kansas         2015 Q1                        1.3        1.1        14.2
#                2016 Q1                       10.6        0.1         1.2
#                2017 Q1                        2.9        0.0         3.6
#                2018 Q1                       20.3        1.0         4.3
#                2021 Q1                        2.8        0.0         0.0
# Kentucky       2015 Q1                       10.7        2.5         2.5
#                2018 Q1                       29.6        0.9        11.0
#                2020 Q1                        2.6        2.0         0.3
#                2021 Q1                       16.9        0.0         0.0
# Louisiana      2019 Q4                       18.5        3.5         0.7
#                2020 Q4                        2.9        0.0         0.0
# Maine          2016 Q1                        0.4        0.3         0.0
#                2018 Q1                        0.6        0.2         0.0
#                     Q3                        1.0        1.1         0.0
#                2020 Q1                        1.2        0.7         0.0
# Maryland       2016 Q1                        0.1        0.0        11.0
#                     Q3                        4.8        0.1         0.7
#                2017 Q1                        3.3        1.0         1.0
#                2018 Q1                        5.6        4.4         1.5
#                2020 Q1                        1.5        0.1         0.0
#                2021 Q4                       12.2        0.0         0.0
# Massachusetts  2015 Q1                        3.5        2.1         2.8
#                2016 Q1                        5.2        0.7         0.0
#                2018 Q1                        1.0        0.8         0.8
#                2021 Q2                       44.3        0.0        44.0
# Michigan       2016 Q1                        0.2        0.0         0.5
#                2017 Q1                        0.3        0.0         1.9
#                2020 Q1                        0.5        0.2         0.2
#                     Q2                       11.5        2.2         6.0
#                2021 Q2                        2.7        0.8         3.5
# Minnesota      2020 Q1                        0.0        0.0         0.2
#                2021 Q1                        0.6        0.0         2.5
#                     Q4                        0.0        0.0         3.4
# Mississippi    2015 Q3                        2.2        0.0         1.1
#                2016 Q1                        1.1        0.0         2.0
#                     Q4                        6.0        0.1         0.0
#                2018 Q3                        8.6        0.0         0.5
#                     Q4                        6.7        0.2         0.5
# Missouri       2016 Q1                        6.2        0.3         5.4
#                2017 Q1                       15.2        0.5         2.6
#                     Q3                       36.0        2.8        34.0
#                2018 Q2                       13.2        0.8         1.5
#                2020 Q1                        3.4        0.9         1.6
# Montana        2016 Q1                        0.0        0.0         0.6
#                2020 Q1                        0.0        0.0         0.0
# Nebraska       2015 Q1                        0.1        0.1         0.5
#                2018 Q2                        0.4        0.4         3.2
#                2020 Q1                        0.1        0.1         0.0
#                     Q2                        1.0        4.4        10.9
#                2021 Q1                        0.0        0.0         1.5
#                     Q2                        0.0        0.0         7.4
# New Jersey     2015 Q4                        2.2        0.0         0.4
#                2018 Q3                        5.1        0.2         0.1
#                2020 Q1                        2.9        0.5         0.1
#                2021 Q1                        1.5        1.0         1.3
#                2022 Q1                        3.9        0.0         0.0
# New Mexico     2016 Q1                        0.4       31.5         0.0
#                2018 Q2                        0.1        0.3         0.0
#                2019 Q4                        0.3        0.4         0.0
#                2021 Q1                        0.1        0.0         0.0
# New York       2016 Q1                        5.9        1.5         7.6
#                2018 Q2                       20.3       15.4         6.0
#                2020 Q1                        2.9        0.0         0.0
#                     Q2                        2.6        0.6         0.2
#                2021 Q1                        3.9        0.6         0.5
# North Carolina 2016 Q1                        2.5        1.9         2.7
#                2017 Q4                       16.3        3.9         1.5
#                2021 Q1                        7.3        0.0         0.0
# North Dakota   2017 Q2                        3.6        2.8         5.4
#                2020 Q2                        1.7        2.6         3.0
#                2021 Q2                        0.7        0.0         0.0
#                2022 Q1                        0.0        0.0         0.0
# Ohio           2016 Q1                        4.4        0.2         1.3
#                2018 Q1                       10.0        6.5         3.2
# Oklahoma       2015 Q1                       10.1        0.5         0.0
#                2016 Q1                        2.6        0.1         0.6
#                2018 Q1                        8.5        3.2         0.1
#                     Q3                       51.1        0.1        23.5
#                2020 Q4                        1.1        0.0         0.0
# Oregon         2021 Q1                       10.7        1.4         0.0
#                     Q2                        8.3        6.2        10.1
#                2022 Q1                        0.0        0.0         1.4
# Other States   2015 Q1                        0.1        0.0         0.1
#                2016 Q1                        0.0        0.0         0.0
#                     Q4                        9.3        9.3         9.6
#                2017 Q1                        0.8        6.6         2.6
#                2020 Q2                        1.1        0.7         0.0
# Pennsylvania   2015 Q1                        6.3        1.9         1.9
#                2016 Q1                        4.3        0.3         3.8
#                2018 Q1                        5.6        3.3         9.3
#                2021 Q1                       11.6        0.0         0.0
# South Carolina 2016 Q4                       27.1       23.3        24.6
#                2021 Q1                       10.1        0.0         3.2
# South Dakota   2020 Q2                       31.4        4.8         0.4
# Tennessee      2016 Q1                        7.1        0.2         3.7
#                     Q4                       21.6        0.0         1.1
#                2017 Q4                       18.9        0.2         2.0
# Texas          2018 Q4                       18.5        5.5         3.0
#                2019 Q4                       14.0        4.6         4.9
# Utah           2015 Q1                        0.9        0.1         4.4
#                2016 Q1                        7.6        0.1         0.4
#                2017 Q1                        0.0        0.1         0.0
#                2020 Q1                       17.2       17.1         2.3
# Vermont        2016 Q3                        8.0        1.7         0.0
#                     Q4                       41.3       41.2        41.0
#                2018 Q1                        1.2        0.3         0.6
#                     Q4                        1.3        0.0         0.0
#                2021 Q1                        0.0        3.7         0.0
# Virginia       2016 Q4                       19.9        2.0         0.0
#                2021 Q1                        1.0        0.0         1.9
# West Virginia  2016 Q1                        2.9        1.1         0.6
#                2018 Q1                        8.0        2.0         3.4
# Wisconsin      2020 Q1                        1.9        0.4         0.0
#                     Q2                       27.3       25.0        25.1
#                2021 Q1                        0.0        0.0         0.0
#                2022 Q1                        0.0        0.0         6.5
# Wyoming        2016 Q1                        0.5        0.2         3.3
#                2017 Q1                        0.0        0.2         0.0
#                2018 Q1                        0.4        0.1         0.0
#                     Q2                        0.1        2.4         2.3
#                2020 Q1                        0.1        0.1         0.0
#                     Q2                        0.0        0.1         1.1
#                2022 Q1                        0.0        0.0         0.0
#
#                             Other  Unknown  colony_end  colony_end_computed  \
# state          year months
# Alabama        2016 Q1        2.4     11.3      8000.0               7000.0
#                     Q4        6.7      3.3      7000.0               6440.0
# Arizona        2020 Q1       10.1      9.0     26000.0              25650.0
#                2021 Q1        0.5      4.2     26000.0              25500.0
#                2022 Q1        0.0      0.5     31000.0              30400.0
# Arkansas       2015 Q3        1.8      1.4     23000.0              21500.0
#                     Q4        8.5      0.6     27000.0              26500.0
#                2017 Q2        3.4      3.1     29000.0              20100.0
#                     Q4       24.1      0.4     22000.0              20000.0
#                2018 Q2       11.4     16.6     29000.0              24000.0
#                     Q4        5.3      2.2     28000.0              25110.0
# Colorado       2015 Q1        2.6      5.9     12000.0              11200.0
#                2016 Q1        3.0      0.2      9500.0               6430.0
#                2021 Q1        1.1      7.8     17000.0              16710.0
#                2022 Q1        3.4      2.6      8000.0               7960.0
# Connecticut    2016 Q2        4.4      1.2      3100.0               2790.0
#                     Q4        5.8      3.2      3100.0               2860.0
#                2017 Q1        6.1      5.6      3000.0               2820.0
# ...
#                2020 Q1        2.1      3.4      6500.0               6430.0
# Montana        2016 Q1        0.2      0.1     62000.0              58660.0
#                2020 Q1        0.5      0.0     48000.0              47850.0
# Nebraska       2015 Q1        0.3      3.0     29000.0              28520.0
#                2018 Q2        7.5      4.0     52000.0              40400.0
#                2020 Q1        0.3      0.8     16500.0              16400.0
#                     Q2        0.1      2.6     47000.0              44200.0
#                2021 Q1        1.7      0.7     18500.0              18160.0
#                     Q2        3.2      1.3     45000.0              43700.0
# New Jersey     2015 Q4        0.4      1.2      8500.0               8250.0
#                2018 Q3        1.0      0.4     15500.0              13930.0
#                2020 Q1        3.2      2.3      7000.0               6860.0
#                2021 Q1        1.2      0.8     14500.0              14250.0
#                2022 Q1        0.6      1.8     16000.0              15950.0
# New Mexico     2016 Q1        1.5      0.3      6500.0               4810.0
#                2018 Q2        0.2      1.0      6000.0               4540.0
#                2019 Q4        2.6      0.0      6000.0               5960.0
#                2021 Q1        6.5      1.9      5500.0               5470.0
# New York       2016 Q1        9.5      2.6     31000.0              27140.0
#                2018 Q2       17.3      3.6     55000.0              40700.0
#                2020 Q1        1.7      7.7     33000.0              32530.0
#                     Q2        3.6      0.6     61000.0              57600.0
#                2021 Q1        5.7      4.8     29000.0              28500.0
# North Carolina 2016 Q1        4.0      2.5     23000.0              21580.0
#                2017 Q4       11.7      6.7     18500.0              18060.0
#                2021 Q1        0.6      0.5     22000.0              21600.0
# North Dakota   2017 Q2        3.0      0.4    470000.0             394000.0
#                2020 Q2        2.9      1.5    455000.0             406500.0
#                2021 Q2        2.0      0.0    510000.0             395400.0
#                2022 Q1        0.0      0.0     90000.0              89180.0
# Ohio           2016 Q1       10.2      5.3     14000.0              12560.0
#                2018 Q1       15.8     11.6     11000.0              10300.0
# Oklahoma       2015 Q1        2.1      2.9     25000.0              22600.0
#                2016 Q1        2.4     41.5     12000.0               3160.0
#                2018 Q1        3.1      2.0     15500.0              15190.0
#                     Q3       17.2     23.4      2200.0               1750.0
#                2020 Q4        0.0      0.8     28000.0              27950.0
# Oregon         2021 Q1        1.2      0.6     80000.0              78500.0
#                     Q2        6.5      1.8    130000.0             105700.0
#                2022 Q1        0.0      1.1     94000.0              92400.0
# Other States   2015 Q1        0.9      0.0      8600.0               7780.0
#                2016 Q1       13.3      0.0      7970.0               7050.0
#                     Q4        2.3      1.4      6190.0               5900.0
#                2017 Q1        1.8      2.5      5530.0               5080.0
#                2020 Q2        0.3      0.3     10630.0               8460.0
# Pennsylvania   2015 Q1       17.8      6.3     15500.0              14860.0
#                2016 Q1        5.5      4.6     11000.0               9820.0
#                2018 Q1        5.9      9.9     15500.0              14600.0
#                2021 Q1        6.8      8.2     20000.0              19600.0
# South Carolina 2016 Q4       25.9      1.9     17000.0              16460.0
#                2021 Q1        4.1      0.9     18500.0              18230.0
# South Dakota   2020 Q2       37.5      5.3    230000.0             208900.0
# Tennessee      2016 Q1       10.1     10.9      8000.0               7400.0
#                     Q4        2.2      3.1      8500.0               8280.0
#                2017 Q4        7.5     15.3     10000.0               9430.0
# Texas          2018 Q4        6.2      3.7    260000.0             254000.0
#                2019 Q4        5.8      1.4    235000.0             230500.0
# Utah           2015 Q1        3.0      0.5     24000.0              23200.0
#                2016 Q1        1.9      0.6     14500.0              11510.0
#                2017 Q1        2.0      0.3     19000.0              18700.0
#                2020 Q1       15.7     22.4     21000.0              20800.0
# Vermont        2016 Q3        2.4      0.8      6500.0               6270.0
#                     Q4        0.4      0.0      6500.0               6260.0
#                2018 Q1        2.0      0.8      5500.0               4950.0
#                     Q4        0.8      0.7      6500.0               6340.0
#                2021 Q1       10.1      0.0      7000.0               6870.0
# Virginia       2016 Q4        1.8      5.1      8000.0               6500.0
#                2021 Q1        3.9      4.9      8000.0               7900.0
# West Virginia  2016 Q1        6.9      6.5      7000.0               5800.0
#                2018 Q1       20.8      4.9      7000.0               6830.0
# Wisconsin      2020 Q1        2.7      3.1     27000.0              26500.0
#                     Q2       25.8     26.1     68000.0              62800.0
#                2021 Q1        3.6      3.2     42000.0              41500.0
#                2022 Q1        2.0      0.5     52000.0              51600.0
# Wyoming        2016 Q1        1.0      1.6      6500.0               4660.0
#                2017 Q1        0.6      0.0     15000.0              14700.0
#                2018 Q1        2.1      1.0      8500.0               7850.0
#                     Q2        2.9      4.2     33000.0              22900.0
#                2020 Q1        0.8      1.7     17500.0              17310.0
#                     Q2        3.5      1.2     33000.0              24700.0
#                2022 Q1        1.2      0.8      8000.0               7840.0
#
#                             differences  problem_check
# state          year months
# Alabama        2016 Q1          -1000.0         -820.0
#                     Q4           -560.0         -550.0
# Arizona        2020 Q1           -350.0         -230.0
#                2021 Q1           -500.0         -320.0
#                2022 Q1           -600.0         -590.0
# Arkansas       2015 Q3          -1500.0        -1290.0
#                     Q4           -500.0         -500.0
#                2017 Q2          -8900.0        -7600.0
#                     Q4          -2000.0        -1560.0
#                2018 Q2          -5000.0        -3100.0
#                     Q4          -2890.0        -2660.0
# Colorado       2015 Q1           -800.0         -660.0
#                2016 Q1          -3070.0        -3050.0
#                2021 Q1           -290.0         -260.0
#                2022 Q1            -40.0          -30.0
# Connecticut    2016 Q2           -310.0         -250.0
#                     Q4           -240.0         -240.0
#                2017 Q1           -180.0          -70.0
#                     Q3           -580.0         -560.0
#                2018 Q1           -620.0         -290.0
#                     Q3           -350.0          -40.0
#                2020 Q1            -70.0          -70.0
#                     Q4            -80.0          -60.0
# Georgia        2016 Q4         -10000.0        -9550.0
#                2017 Q4          -5700.0        -3500.0
# Hawaii         2017 Q2          -2540.0        -1630.0
#                     Q3           -670.0         -650.0
#                2020 Q2          -2800.0         -500.0
# Illinois       2015 Q1           -900.0         -510.0
#                2016 Q1          -2330.0        -2310.0
#                     Q2           -540.0         -160.0
#                     Q4          -2720.0        -2720.0
#                2017 Q1           -800.0         -650.0
#                2018 Q1           -900.0         -270.0
#                     Q3           -960.0         -540.0
#                2020 Q1           -200.0          -40.0
# Indiana        2016 Q4           -680.0         -680.0
#                2017 Q1           -200.0         -130.0
#                2018 Q1           -700.0         -670.0
#                2021 Q1           -200.0         -180.0
# Iowa           2018 Q1           -880.0         -770.0
#                2021 Q3           -500.0         -370.0
#                2022 Q1           -190.0         -160.0
# Kansas         2015 Q1           -150.0          -80.0
#                2016 Q1           -980.0         -780.0
#                2017 Q1           -670.0         -290.0
#                2018 Q1           -650.0         -240.0
#                2021 Q1           -100.0          -90.0
# Kentucky       2015 Q1           -850.0         -850.0
#                2018 Q1           -380.0         -360.0
#                2020 Q1           -200.0          -80.0
#                2021 Q1           -100.0          -20.0
# Louisiana      2019 Q4           -230.0         -150.0
#                2020 Q4           -670.0          -50.0
# Maine          2016 Q1            -70.0          -70.0
#                2018 Q1           -500.0         -470.0
#                     Q3           -330.0         -160.0
#                2020 Q1            -30.0          -30.0
# Maryland       2016 Q1          -2860.0        -2840.0
#                     Q3           -300.0         -280.0
#                2017 Q1           -330.0          -70.0
#                2018 Q1           -500.0         -310.0
#                2020 Q1           -140.0         -110.0
#                2021 Q4            -20.0          -20.0
# Massachusetts  2015 Q1           -240.0         -120.0
#                2016 Q1          -1450.0        -1120.0
#                2018 Q1           -560.0         -270.0
#                2021 Q2          -2410.0        -2100.0
# Michigan       2016 Q1          -5700.0        -5590.0
#                2017 Q1           -400.0         -270.0
#                2020 Q1          -1200.0        -1100.0
#                     Q2         -10100.0         -100.0
#                2021 Q2         -16500.0        -8500.0
# Minnesota      2020 Q1          -1000.0         -960.0
#                2021 Q1          -1300.0        -1160.0
#                     Q4           -600.0         -250.0
# Mississippi    2015 Q3           -240.0         -130.0
#                2016 Q1          -3500.0        -1800.0
#                     Q4          -3070.0        -3010.0
#                2018 Q3           -790.0         -140.0
#                     Q4          -2670.0        -2620.0
# Missouri       2016 Q1           -770.0         -480.0
#                2017 Q1           -300.0         -290.0
#                     Q3           -760.0         -450.0
#                2018 Q2          -1590.0         -790.0
#                2020 Q1            -70.0          -70.0
# Montana        2016 Q1          -3340.0        -3340.0
#                2020 Q1           -150.0         -150.0
# Nebraska       2015 Q1           -480.0         -170.0
#                2018 Q2         -11600.0       -10900.0
#                2020 Q1           -100.0         -100.0
#                     Q2          -2800.0        -1700.0
#                2021 Q1           -340.0         -340.0
#                     Q2          -1300.0         -490.0
# New Jersey     2015 Q4           -250.0         -240.0
#                2018 Q3          -1570.0        -1350.0
#                2020 Q1           -140.0         -100.0
#                2021 Q1           -250.0         -170.0
#                2022 Q1            -50.0          -20.0
# New Mexico     2016 Q1          -1690.0        -1620.0
#                2018 Q2          -1460.0        -1010.0
#                2019 Q4            -40.0          -30.0
#                2021 Q1            -30.0          -30.0
# New York       2016 Q1          -3860.0        -2460.0
#                2018 Q2         -14300.0       -12000.0
#                2020 Q1           -470.0         -100.0
#                     Q2          -3400.0         -100.0
#                2021 Q1           -500.0         -120.0
# North Carolina 2016 Q1          -1420.0         -580.0
#                2017 Q4           -440.0         -150.0
#                2021 Q1           -400.0         -290.0
# North Dakota   2017 Q2         -76000.0       -39000.0
#                2020 Q2         -48500.0       -11500.0
#                2021 Q2        -114600.0      -111100.0
#                2022 Q1           -820.0         -820.0
# Ohio           2016 Q1          -1440.0        -1340.0
#                2018 Q1           -700.0         -120.0
# Oklahoma       2015 Q1          -2400.0        -2140.0
#                2016 Q1          -8840.0        -8330.0
#                2018 Q1           -310.0          -70.0
#                     Q3           -450.0         -440.0
#                2020 Q4            -50.0          -50.0
# Oregon         2021 Q1          -1500.0         -890.0
#                     Q2         -24300.0        -4800.0
#                2022 Q1          -1600.0        -1290.0
# Other States   2015 Q1           -820.0         -670.0
#                2016 Q1           -920.0         -910.0
#                     Q4           -290.0         -290.0
#                2017 Q1           -450.0         -400.0
#                2020 Q2          -2170.0         -670.0
# Pennsylvania   2015 Q1           -640.0         -640.0
#                2016 Q1          -1180.0         -840.0
#                2018 Q1           -900.0         -230.0
#                2021 Q1           -400.0         -360.0
# South Carolina 2016 Q4           -540.0         -170.0
#                2021 Q1           -270.0          -80.0
# South Dakota   2020 Q2         -21100.0        -6600.0
# Tennessee      2016 Q1           -600.0         -450.0
#                     Q4           -220.0         -210.0
#                2017 Q4           -570.0         -250.0
# Texas          2018 Q4          -6000.0        -5930.0
#                2019 Q4          -4500.0        -2800.0
# Utah           2015 Q1           -800.0         -510.0
#                2016 Q1          -2990.0        -2890.0
#                2017 Q1           -300.0         -240.0
#                2020 Q1           -200.0         -200.0
# Vermont        2016 Q3           -230.0         -180.0
#                     Q4           -240.0         -230.0
#                2018 Q1           -550.0         -550.0
#                     Q4           -160.0         -140.0
#                2021 Q1           -130.0          -60.0
# Virginia       2016 Q4          -1500.0        -1490.0
#                2021 Q1           -100.0          -50.0
# West Virginia  2016 Q1          -1200.0        -1190.0
#                2018 Q1           -170.0         -110.0
# Wisconsin      2020 Q1           -500.0         -130.0
#                     Q2          -5200.0         -600.0
#                2021 Q1           -500.0         -330.0
#                2022 Q1           -400.0         -160.0
# Wyoming        2016 Q1          -1840.0        -1840.0
#                2017 Q1           -300.0         -300.0
#                2018 Q1           -650.0         -650.0
#                     Q2         -10100.0        -7800.0
#                2020 Q1           -190.0         -130.0
#                     Q2          -8300.0        -6200.0
#                2022 Q1           -160.0         -160.0

# %%
fig, ax = plt.subplots(figsize=(16,15))
plt.title('Differences between computed colony (without colony_repo) and the given one at the end of the trimester')
plt.ylabel('Difference values')
df_states["differences"].unstack(level=0).plot(ax=ax,color=custom_states)
#last "differences" value in time for each state (Q2 of 2022) does not hold since it is computed with respect to
#the first timestamp of the next state.
plt.axhline(y=+500, color='r', linestyle='-')
plt.axhline(y=-500, color='r', linestyle='-')
plt.ylim([-10000,+10000])
# Out:
# (-10000.0, 10000.0)

# %%
#Let's check in which quarters "problem_check" has negative values
df_states[df_states.differences < 0].index.get_level_values(2).value_counts().sort_index()
# Out:
# Q1    152
# Q2     71
# Q3     81
# Q4     59
# Name: months, dtype: int64

# %% [markdown]
# **Conclusion**: <br>
# Either our understanding of datapoints is not correct, or the values reported are not accurate since we cannot explain the link between the number of colonies in the different trimesters

# %% [markdown]
# # USDA Dataset - Check the differences with respect to TidyTuesday Dataset

# %%
#new code using "cleaned_by_state.csv" preprocessed as in "main.Rmd"
#rows of dataset for 2019-Q2 already removed and NaN values substitued with 0

df_new = pd.read_csv(start_path + "/data/new_data/cleaned_by_state.csv")
print(df_new.Period.unique())
map_quarters2 = {
    'JAN THRU MAR': "Q1",
    'APR THRU JUN': "Q2",
    'JUL THRU SEP': "Q3",
    'OCT THRU DEC': "Q4"
}
df_new['Period'] = df_new['Period'].map(map_quarters2)
df_new.State = df_new.State.apply(lambda x: x.lower())
df_new.rename(columns = {"Year": "year", "Period": "months", "State": "state"}, inplace=True)
df_new = df_new.set_index(['year', 'months', 'state'])
df_new.sort_index(inplace=True)
df_new.head()
# Out:
# ['APR THRU JUN' 'JAN THRU MAR' 'JUL THRU SEP' 'OCT THRU DEC']
#                        State ANSI  \
# year months state
# 2015 Q1     alabama            01
#             arizona            04
#             arkansas           05
#             california         06
#             colorado           08
#
#                         HONEY, BEE COLONIES - ADDED & REPLACED, MEASURED IN COLONIES  \
# year months state
# 2015 Q1     alabama                                                  2800
#             arizona                                                  3400
#             arkansas                                                 1200
#             california                                             250000
#             colorado                                                  200
#
#                         HONEY, BEE COLONIES - INVENTORY, MAX, MEASURED IN COLONIES  \
# year months state
# 2015 Q1     alabama                                                7000.0
#             arizona                                               35000.0
#             arkansas                                              14000.0
#             california                                          1690000.0
#             colorado                                              12500.0
#
#                         HONEY, BEE COLONIES - LOSS, COLONY COLLAPSE DISORDER, MEASURED IN COLONIES  \
# year months state
# 2015 Q1     alabama                                                     0
#             arizona                                                     0
#             arkansas                                                    0
#             california                                                  0
#             colorado                                                    0
#
#                         HONEY, BEE COLONIES - LOSS, DEADOUT, MEASURED IN COLONIES  \
# year months state
# 2015 Q1     alabama                                                1800.0
#             arizona                                                4600.0
#             arkansas                                               1500.0
#             california                                           255000.0
#             colorado                                               1500.0
#
#                         HONEY, BEE COLONIES - LOSS, DEADOUT, MEASURED IN PCT OF COLONIES  \
# year months state
# 2015 Q1     alabama                                                    26
#             arizona                                                    13
#             arkansas                                                   11
#             california                                                 15
#             colorado                                                   12
#
#                         HONEY, BEE COLONIES, AFFECTED BY DISEASE - INVENTORY, MEASURED IN PCT OF COLONIES  \
# year months state
# 2015 Q1     alabama                                                   0.0
#             arizona                                                   0.1
#             arkansas                                                  1.5
#             california                                                3.0
#             colorado                                                  1.8
#
#                         HONEY, BEE COLONIES, AFFECTED BY OTHER CAUSES - INVENTORY, MEASURED IN PCT OF COLONIES  \
# year months state
# 2015 Q1     alabama                                                   9.1
#             arizona                                                   1.8
#             arkansas                                                  1.0
#             california                                                6.5
#             colorado                                                  2.6
#
#                         HONEY, BEE COLONIES, AFFECTED BY PESTICIDES - INVENTORY, MEASURED IN PCT OF COLONIES  \
# year months state
# 2015 Q1     alabama                                                   2.2
#             arizona                                                   0.0
#             arkansas                                                  3.4
#             california                                                7.5
#             colorado                                                  0.6
#
#                         HONEY, BEE COLONIES, AFFECTED BY PESTS ((EXCL VARROA MITES)) - INVENTORY, MEASURED IN PCT OF COLONIES  \
# year months state
# 2015 Q1     alabama                                                   5.4
#             arizona                                                  20.5
#             arkansas                                                 11.4
#             california                                                7.2
#             colorado                                                  0.9
#
#                         HONEY, BEE COLONIES, AFFECTED BY UNKNOWN CAUSES - INVENTORY, MEASURED IN PCT OF COLONIES  \
# year months state
# 2015 Q1     alabama                                                   9.4
#             arizona                                                   3.1
#             arkansas                                                  1.0
#             california                                                2.8
#             colorado                                                  5.9
#
#                         HONEY, BEE COLONIES, AFFECTED BY VARROA MITES - INVENTORY, MEASURED IN PCT OF COLONIES  \
# year months state
# 2015 Q1     alabama                                                  10.0
#             arizona                                                  26.9
#             arkansas                                                 17.6
#             california                                               24.7
#             colorado                                                 14.6
#
#                         HONEY, BEE COLONIES, RENOVATED - INVENTORY, MEASURED IN COLONIES  \
# year months state
# 2015 Q1     alabama                                                 250.0
#             arizona                                                2100.0
#             arkansas                                                 90.0
#             california                                           124000.0
#             colorado                                                140.0
#
#                         HONEY, BEE COLONIES, RENOVATED - INVENTORY, MEASURED IN PCT OF COLONIES  \
# year months state
# 2015 Q1     alabama                                                     4
#             arizona                                                     6
#             arkansas                                                    1
#             california                                                  7
#             colorado                                                    1
#
#                         HONEY, BEE COLONIES - INVENTORY, MEASURED IN COLONIES
# year months state
# 2015 Q1     alabama                                                7000.0
#             arizona                                               35000.0
#             arkansas                                              13000.0
#             california                                          1440000.0
#             colorado                                               3500.0

# %%
#df_years.columns

df_new.drop(df_new.columns[[0, 3]], axis=1, inplace=True)
df_new.columns = ['colony_added', 'colony_max', 'colony_lost', 'colony_lost_pct', 'Disesases', 'Other', 'Pesticides', 'Other pests/parasites', 'Unknown', 'Varroa mites', 'colony_reno', 'colony_reno_pct', 'colony_n']
df_new = df_new[df_years.columns] #reorder the columns of df_new to match the ones of df_years
df_new.head()
# Out:
#                          colony_n  colony_max  colony_lost  colony_lost_pct  \
# year months state
# 2015 Q1     alabama        7000.0      7000.0       1800.0               26
#             arizona       35000.0     35000.0       4600.0               13
#             arkansas      13000.0     14000.0       1500.0               11
#             california  1440000.0   1690000.0     255000.0               15
#             colorado       3500.0     12500.0       1500.0               12
#
#                         colony_added  colony_reno  colony_reno_pct  \
# year months state
# 2015 Q1     alabama             2800        250.0                4
#             arizona             3400       2100.0                6
#             arkansas            1200         90.0                1
#             california        250000     124000.0                7
#             colorado             200        140.0                1
#
#                         Varroa mites  Other pests/parasites  Disesases  \
# year months state
# 2015 Q1     alabama             10.0                    5.4        0.0
#             arizona             26.9                   20.5        0.1
#             arkansas            17.6                   11.4        1.5
#             california          24.7                    7.2        3.0
#             colorado            14.6                    0.9        1.8
#
#                         Pesticides  Other  Unknown
# year months state
# 2015 Q1     alabama            2.2    9.1      9.4
#             arizona            0.0    1.8      3.1
#             arkansas           3.4    1.0      1.0
#             california         7.5    6.5      2.8
#             colorado           0.6    2.6      5.9

# %%
df_new.isna().sum()
# Out:
# colony_n                 0
# colony_max               0
# colony_lost              0
# colony_lost_pct          0
# colony_added             0
# colony_reno              0
# colony_reno_pct          0
# Varroa mites             0
# Other pests/parasites    0
# Disesases                0
# Pesticides               0
# Other                    0
# Unknown                  0
# dtype: int64

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1334 entries, (2015, 'Q1', 'alabama') to (2022, 'Q2', 'wyoming')
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   colony_n               1334 non-null   float64
#  1   colony_max             1334 non-null   float64
#  2   colony_lost            1334 non-null   float64
#  3   colony_lost_pct        1334 non-null   int64
#  4   colony_added           1334 non-null   int64
#  5   colony_reno            1334 non-null   float64
#  6   colony_reno_pct        1334 non-null   int64
#  7   Varroa mites           1334 non-null   float64
#  8   Other pests/parasites  1334 non-null   float64
#  9   Disesases              1334 non-null   float64
#  10  Pesticides             1334 non-null   float64
#  11  Other                  1334 non-null   float64
#  12  Unknown                1334 non-null   float64
# dtypes: float64(10), int64(3)
# memory usage: 141.5+ KB

# %%
df_years_new = df_years.fillna(value=0, inplace=False) #Fill NaN also for stressor features of df_years
df_years_new.isna().sum()
# Out:
# colony_n                 0
# colony_max               0
# colony_lost              0
# colony_lost_pct          0
# colony_added             0
# colony_reno              0
# colony_reno_pct          0
# Varroa mites             0
# Other pests/parasites    0
# Disesases                0
# Pesticides               0
# Other                    0
# Unknown                  0
# dtype: int64

# %%
#name of the state as lowercase in df_years_new to match the names of df_new:
df_years_new = df_years_new.reset_index()
df_years_new.state = df_years_new.state.apply(lambda x: x.lower())
df_years_new = df_years_new.set_index(['year', 'months', 'state'])

# %%
len(df_new.index.levels[2].tolist()) == len(df_years_new.index.levels[2].tolist())
df_new.index.levels[2]
# --> No overall United States values here
# Out:
# Index(['alabama', 'arizona', 'arkansas', 'california', 'colorado',
#        'connecticut', 'florida', 'georgia', 'hawaii', 'idaho', 'illinois',
#        'indiana', 'iowa', 'kansas', 'kentucky', 'louisiana', 'maine',
#        'maryland', 'massachusetts', 'michigan', 'minnesota', 'mississippi',
#        'missouri', 'montana', 'nebraska', 'new jersey', 'new mexico',
#        'new york', 'north carolina', 'north dakota', 'ohio', 'oklahoma',
#        'oregon', 'other states', 'pennsylvania', 'south carolina',
#        'south dakota', 'tennessee', 'texas', 'utah', 'vermont', 'virginia',
#        'washington', 'west virginia', 'wisconsin', 'wyoming'],
#       dtype='object', name='state')

# %%
#df_new.describe()
#df_years.describe()

#differences between the two dataframes:
df_diff = df_new - df_years_new
#print the rows where at least one value is different from zero:
print(df_diff[(df_diff != 0).any(axis=1)].shape)
df_diff[(df_diff != 0).any(axis=1)] #df_diff[df_diff.values != 0]
# Out:
# (343, 13)
#                             colony_n  colony_max  colony_lost  \
# year months state
# 2016 Q1     alabama              0.0         0.0          0.0
#             arizona              0.0         0.0          0.0
#             arkansas             0.0         0.0          0.0
#             california      -10000.0         0.0     -10000.0
#             colorado         -1000.0      1500.0        180.0
#             florida          30000.0     30000.0      -5000.0
#             georgia              0.0         0.0      -4500.0
#             hawaii               0.0         0.0          0.0
#             idaho             1000.0      1000.0       2000.0
#             illinois          1500.0      2000.0        100.0
#             indiana              0.0         0.0          0.0
#             iowa             -3500.0     -3500.0       -300.0
#             kansas             300.0       300.0        120.0
#             kentucky          -500.0      -500.0          0.0
#             louisiana       -14000.0    -14000.0       1500.0
#             maryland          1000.0      1000.0       -580.0
#             massachusetts        0.0         0.0          0.0
#             michigan             0.0      5000.0          0.0
#             minnesota        -1000.0     -1000.0       -500.0
#             mississippi      -3000.0    -27000.0       1000.0
#             missouri         -1500.0     -1500.0        100.0
#             montana           1000.0     17000.0         60.0
#             nebraska           500.0     -1000.0        390.0
#             new jersey       -2500.0     -2500.0          0.0
#             new mexico           0.0         0.0          0.0
#             new york             0.0      2000.0        200.0
#             north carolina       0.0         0.0        100.0
#             north dakota      7000.0    -36000.0      -8500.0
#             ohio               500.0       500.0      -1300.0
#             oklahoma          7500.0      7500.0        400.0
#             oregon           -2000.0         0.0        100.0
#             other states        50.0        50.0          0.0
#             pennsylvania         0.0         0.0          0.0
#             south carolina       0.0         0.0        100.0
#             south dakota     17000.0    -12000.0       9730.0
#             tennessee            0.0         0.0          0.0
#             texas                0.0     30000.0       1000.0
#             utah                 0.0      2000.0        200.0
#             vermont              0.0         0.0          0.0
#             virginia             0.0         0.0          0.0
#             washington       -1000.0     11000.0        500.0
#             west virginia        0.0       500.0          0.0
#             wisconsin        -2000.0     -2000.0        200.0
#             wyoming              0.0      1500.0          0.0
#      Q2     vermont              0.0         0.0          0.0
# 2017 Q1     alabama              0.0         0.0          0.0
#             arizona              0.0         0.0          0.0
#             arkansas             0.0         0.0          0.0
#             california       20000.0     30000.0      23000.0
#             florida              0.0         0.0          0.0
#             georgia              0.0         0.0          0.0
#             illinois             0.0         0.0          0.0
#             kansas               0.0         0.0          0.0
#             louisiana            0.0         0.0          0.0
#             massachusetts        0.0         0.0          0.0
#             minnesota            0.0         0.0          0.0
#             mississippi          0.0         0.0          0.0
#             missouri           500.0         0.0          0.0
#             montana              0.0         0.0          0.0
#             nebraska             0.0         0.0          0.0
#             new jersey           0.0      -500.0          0.0
#             new york             0.0         0.0          0.0
#             north dakota         0.0         0.0          0.0
#             oklahoma             0.0         0.0          0.0
#             pennsylvania         0.0         0.0       -200.0
#             texas             5000.0     10000.0      14000.0
#             utah                 0.0       500.0          0.0
#             vermont              0.0         0.0          0.0
#             washington           0.0         0.0          0.0
#      Q2     arizona              0.0         0.0          0.0
#             arkansas             0.0      7000.0          0.0
#             california     -160000.0   -190000.0       8000.0
#             colorado             0.0      2000.0       1000.0
#             connecticut          0.0         0.0          0.0
#             florida              0.0      5000.0      10000.0
#             georgia           5000.0     -5000.0       2000.0
#             hawaii               0.0         0.0         10.0
#             idaho                0.0         0.0       1000.0
#             illinois          -500.0      -500.0          0.0
#             indiana              0.0         0.0          0.0
#             iowa              -500.0         0.0        400.0
#             kansas            -600.0      1100.0         10.0
#             kentucky           500.0       500.0        340.0
#             louisiana            0.0      6000.0          0.0
#             maine                0.0     -7000.0          0.0
#             maryland             0.0         0.0          0.0
#             massachusetts      600.0         0.0         10.0
#             michigan             0.0     21000.0       2900.0
#             minnesota        -2000.0         0.0       7000.0
#             mississippi          0.0         0.0          0.0
#             missouri          -500.0      -500.0         10.0
#             montana           1000.0      1000.0       -100.0
#             nebraska         -1000.0    -20000.0        860.0
#             new jersey        -500.0         0.0          0.0
#             new mexico           0.0         0.0        100.0
#             new york             0.0      2000.0          0.0
#             north carolina       0.0         0.0       1400.0
#             north dakota      3000.0     65000.0       5500.0
#             ohio                 0.0       500.0          0.0
#             oklahoma         -8000.0     -8000.0          0.0
#             oregon          -13000.0    -16000.0          0.0
#             other states       120.0       120.0         10.0
#             pennsylvania       500.0      1000.0         30.0
#             south carolina       0.0         0.0          0.0
#             south dakota     -4000.0     16000.0       7000.0
#             tennessee            0.0         0.0        200.0
#             texas                0.0      5000.0      10000.0
#             utah              2000.0     -4000.0        400.0
#             virginia             0.0       500.0          0.0
#             washington      -14000.0    -21000.0        500.0
#             west virginia        0.0         0.0         30.0
#             wisconsin            0.0         0.0       1100.0
#             wyoming              0.0         0.0        200.0
# 2018 Q1     california           0.0         0.0      -5000.0
#             florida              0.0         0.0       4000.0
#             hawaii            2000.0      2000.0          0.0
#             iowa                 0.0     -1000.0        800.0
#             kansas               0.0         0.0          0.0
#             kentucky             0.0         0.0       -400.0
#             maine                0.0         0.0        170.0
#             maryland             0.0         0.0        100.0
#             massachusetts     -100.0      -100.0          0.0
#             michigan             0.0      3000.0      -1000.0
#             minnesota            0.0         0.0          0.0
#             north dakota      2000.0      2000.0          0.0
#             ohio                 0.0         0.0        500.0
#             oregon               0.0         0.0        700.0
#             other states       100.0       500.0          0.0
#             pennsylvania         0.0       500.0       1800.0
#             tennessee            0.0         0.0        400.0
#             texas                0.0         0.0      10000.0
#             vermont              0.0         0.0        240.0
#             washington           0.0      1000.0          0.0
#             west virginia        0.0         0.0        500.0
#             wisconsin            0.0         0.0          0.0
#             wyoming              0.0      1000.0          0.0
#      Q2     alabama           -500.0         0.0       -160.0
#             arizona            500.0         0.0          0.0
#             arkansas          3000.0      4500.0        500.0
#             california      -10000.0     10000.0      40000.0
#             colorado             0.0      1000.0        700.0
#             florida         -20000.0     -5000.0       8000.0
#             georgia          -3000.0      3000.0       2000.0
#             hawaii            2000.0      2000.0        100.0
#             idaho            -1000.0     -1000.0       1700.0
#             illinois             0.0         0.0        200.0
#             indiana              0.0       500.0          0.0
#             kansas               0.0         0.0        130.0
#             kentucky           700.0         0.0        460.0
#             louisiana            0.0         0.0        430.0
#             maine                0.0      6000.0       2000.0
#             massachusetts     -100.0       500.0          0.0
#             michigan          1000.0      1000.0       1500.0
#             minnesota            0.0      8000.0       2000.0
#             mississippi      -3000.0     -4000.0      -1600.0
#             missouri             0.0         0.0          0.0
#             montana              0.0      5000.0        700.0
#             nebraska             0.0      6000.0       -600.0
#             new jersey           0.0         0.0          0.0
#             new mexico           0.0         0.0          0.0
#             new york             0.0      6000.0       -600.0
#             north carolina       0.0         0.0       1300.0
#             north dakota      2000.0     30000.0      12000.0
#             ohio                 0.0         0.0        400.0
#             oklahoma             0.0         0.0        100.0
#             oregon               0.0      1000.0          0.0
#             other states       120.0      1010.0        120.0
#             pennsylvania         0.0         0.0          0.0
#             south carolina       0.0         0.0          0.0
#             south dakota      -500.0      8000.0       5000.0
#             tennessee            0.0         0.0          0.0
#             texas                0.0      5000.0       7000.0
#             utah                 0.0         0.0        200.0
#             virginia             0.0       500.0         10.0
#             washington           0.0         0.0       1000.0
#             west virginia        0.0         0.0         80.0
#             wisconsin         2000.0      6000.0        500.0
#             wyoming              0.0      6000.0        100.0
# 2019 Q1     kansas               0.0         0.0          0.0
# 2020 Q1     alabama              0.0     -1000.0          0.0
#             arizona              0.0     -1000.0       2000.0
#             arkansas             0.0     -1000.0        400.0
#             colorado             0.0     -3000.0         20.0
#             connecticut          0.0      -300.0          0.0
#             florida              0.0     -5000.0          0.0
#             georgia              0.0     -2000.0          0.0
#             hawaii               0.0         0.0        300.0
#             idaho                0.0         0.0          0.0
#             illinois             0.0     -1500.0        300.0
#             indiana              0.0      -500.0          0.0
#             iowa                 0.0     -4000.0          0.0
#             kansas               0.0      -500.0         10.0
#             kentucky             0.0       500.0          0.0
#             maine                0.0      -400.0         30.0
#             maryland             0.0      -500.0       1260.0
#             massachusetts        0.0      -200.0        120.0
#             michigan             0.0     -5000.0       1000.0
#             minnesota            0.0      1000.0        -80.0
#             mississippi          0.0         0.0          0.0
#             missouri             0.0         0.0       3400.0
#             montana              0.0     -1000.0          0.0
#             nebraska             0.0         0.0          0.0
#             new jersey           0.0      -500.0        180.0
#             new mexico           0.0         0.0          0.0
#             new york             0.0         0.0      -1200.0
#             north carolina       0.0      1000.0        300.0
#             north dakota         0.0         0.0       3000.0
#             ohio                 0.0      1000.0        500.0
#             oklahoma             0.0         0.0          0.0
#             oregon               0.0         0.0          0.0
#             other states         0.0      -400.0          0.0
#             pennsylvania         0.0      2000.0       1100.0
#             south carolina       0.0       500.0        600.0
#             south dakota         0.0         0.0          0.0
#             tennessee            0.0         0.0       1200.0
#             utah                 0.0      2000.0        700.0
#             vermont              0.0      -500.0          0.0
#             virginia             0.0         0.0          0.0
#             washington           0.0         0.0          0.0
#             west virginia        0.0         0.0          0.0
#             wisconsin            0.0      2000.0        400.0
#             wyoming              0.0         0.0          0.0
#      Q2     alabama              0.0         0.0          0.0
#             arizona              0.0         0.0          0.0
#             arkansas             0.0         0.0       -100.0
#             california           0.0         0.0      26000.0
#             colorado             0.0         0.0          0.0
#             connecticut          0.0         0.0          0.0
#             florida         -15000.0    -15000.0       1000.0
#             georgia           4000.0      4000.0          0.0
#             hawaii               0.0         0.0        -40.0
#             idaho                0.0         0.0       3500.0
#             indiana              0.0         0.0          0.0
#             iowa                 0.0         0.0          0.0
#             kansas               0.0         0.0        240.0
#             kentucky             0.0         0.0          0.0
#             louisiana            0.0         0.0          0.0
#             maine                0.0         0.0       -600.0
#             maryland             0.0         0.0        -10.0
#             massachusetts      100.0         0.0       -110.0
#             michigan             0.0      6000.0      -1100.0
#             minnesota            0.0         0.0       6500.0
#             mississippi          0.0         0.0       1500.0
#             missouri             0.0         0.0          0.0
#             montana              0.0         0.0      -1800.0
#             nebraska             0.0      2000.0        100.0
#             new jersey           0.0      1000.0        -50.0
#             new mexico           0.0         0.0        950.0
#             new york          1000.0      2000.0       -900.0
#             north dakota         0.0     20000.0       2500.0
#             oklahoma             0.0         0.0          0.0
#             oregon               0.0      1000.0          0.0
#             other states         0.0      2400.0         10.0
#             pennsylvania         0.0      1000.0        -70.0
#             south carolina   -1000.0     -1500.0          0.0
#             south dakota         0.0     15000.0          0.0
#             tennessee            0.0         0.0          0.0
#             texas                0.0         0.0      10000.0
#             utah                 0.0         0.0        100.0
#             vermont              0.0         0.0        -60.0
#             virginia             0.0         0.0          0.0
#             washington           0.0         0.0        400.0
#             wisconsin            0.0      2000.0          0.0
#             wyoming              0.0      6000.0        400.0
# 2021 Q1     alabama              0.0         0.0       -100.0
#             arizona          -1000.0     -1000.0       -500.0
#             arkansas             0.0         0.0       2700.0
#             california      -60000.0     50000.0      82000.0
#             colorado             0.0         0.0         60.0
#             connecticut          0.0         0.0         20.0
#             florida              0.0         0.0          0.0
#             hawaii               0.0         0.0       -100.0
#             idaho            -1000.0     22000.0       -500.0
#             illinois          2000.0       500.0          0.0
#             indiana              0.0         0.0       -100.0
#             iowa                 0.0      1000.0          0.0
#             kansas               0.0      1500.0          0.0
#             kentucky          1500.0      1500.0          0.0
#             louisiana            0.0         0.0       -500.0
#             maryland             0.0         0.0        600.0
#             massachusetts        0.0         0.0        -20.0
#             minnesota        20000.0      5000.0          0.0
#             mississippi      -2000.0         0.0          0.0
#             missouri             0.0         0.0       -600.0
#             montana              0.0         0.0         20.0
#             nebraska             0.0       500.0          0.0
#             new jersey           0.0         0.0        -10.0
#             new mexico           0.0      2000.0         40.0
#             new york             0.0         0.0          0.0
#             north carolina       0.0      3000.0       1900.0
#             north dakota         0.0         0.0          0.0
#             oregon               0.0      1000.0          0.0
#             other states         0.0         0.0          0.0
#             pennsylvania      3000.0      3000.0          0.0
#             south carolina       0.0      -500.0          0.0
#             tennessee            0.0       500.0          0.0
#             texas                0.0     10000.0       7000.0
#             utah                 0.0      1000.0        100.0
#             vermont              0.0         0.0          0.0
#             virginia           500.0       500.0          0.0
#             washington           0.0      3000.0       -500.0
#             west virginia        0.0      1500.0          0.0
#             wisconsin        17000.0      7000.0          0.0
#             wyoming              0.0         0.0        500.0
#      Q2     alabama              0.0         0.0          0.0
#             arizona              0.0         0.0        100.0
#             arkansas           500.0       500.0          0.0
#             california       40000.0         0.0      50000.0
#             colorado             0.0      3000.0       3000.0
#             connecticut          0.0         0.0          0.0
#             florida         -20000.0         0.0          0.0
#             georgia          -1000.0     -1000.0       1000.0
#             hawaii               0.0         0.0       -140.0
#             illinois          -500.0         0.0          0.0
#             indiana          -1000.0       500.0          0.0
#             iowa             -1000.0      2000.0          0.0
#             kansas               0.0         0.0       1030.0
#             louisiana            0.0     -1000.0          0.0
#             maine              200.0         0.0          0.0
#             maryland             0.0         0.0          0.0
#             massachusetts     -300.0      2000.0          0.0
#             michigan         -1000.0     15000.0          0.0
#             minnesota            0.0         0.0          0.0
#             mississippi          0.0         0.0       -200.0
#             missouri             0.0         0.0          0.0
#             montana              0.0         0.0        100.0
#             nebraska             0.0         0.0          0.0
#             new jersey           0.0         0.0          0.0
#             new mexico           0.0         0.0        130.0
#             new york         -1000.0         0.0          0.0
#             north dakota         0.0    100000.0       1600.0
#             ohio                 0.0         0.0          0.0
#             oregon          -20000.0     24000.0          0.0
#             other states        50.0        50.0          0.0
#             pennsylvania         0.0         0.0       -100.0
#             south carolina    -500.0      -500.0       -100.0
#             south dakota         0.0     12000.0        500.0
#             texas           -20000.0         0.0      40000.0
#             utah                 0.0         0.0        300.0
#             vermont              0.0         0.0          0.0
#             washington           0.0         0.0          0.0
#             wisconsin            0.0         0.0       -100.0
#             wyoming              0.0         0.0       -700.0
#
#                             colony_lost_pct  colony_added  colony_reno  \
# year months state
# 2016 Q1     alabama                     0.0         900.0        -90.0
#             arizona                     0.0        1300.0       -810.0
#             arkansas                    0.0         300.0      -1100.0
#             california                 -1.0       35000.0      76000.0
#             colorado                    1.0        1700.0        -10.0
#             florida                    -3.0       13000.0      -3000.0
#             georgia                    -4.0        8000.0      -2800.0
#             hawaii                      0.0           0.0       -570.0
#             idaho                       2.0           0.0      -3200.0
#             illinois                   -2.0         390.0         20.0
#             indiana                     0.0         -10.0          0.0
#             iowa                        3.0           0.0          0.0
#             kansas                      1.0        1400.0       -100.0
#             kentucky                    1.0         280.0        -30.0
#             louisiana                   6.0        2000.0      -2900.0
#             maryland                  -11.0        1160.0        -10.0
#             massachusetts               0.0        1080.0       -190.0
#             michigan                   -2.0           0.0        -30.0
#             minnesota                  -1.0        1600.0        -10.0
#             mississippi                 7.0       37000.0      23300.0
#             missouri                    3.0        4570.0        130.0
#             montana                    -1.0       12500.0          0.0
#             nebraska                    2.0         470.0        -30.0
#             new jersey                  5.0           0.0        -20.0
#             new mexico                  0.0        1390.0        -40.0
#             new york                    0.0         830.0       -800.0
#             north carolina              1.0        1020.0       -610.0
#             north dakota               -4.0        4600.0          0.0
#             ohio                       -8.0           0.0        -50.0
#             oklahoma                  -24.0        4740.0         60.0
#             oregon                      0.0           0.0       -500.0
#             other states                0.0           0.0        -10.0
#             pennsylvania                0.0         260.0       -170.0
#             south carolina              0.0        1100.0      -1420.0
#             south dakota               12.0        1570.0          0.0
#             tennessee                   0.0          80.0        -80.0
#             texas                      -1.0       53000.0       7000.0
#             utah                       -1.0         690.0        -50.0
#             vermont                    -1.0           0.0          0.0
#             virginia                    0.0          60.0        -60.0
#             washington                 -1.0        1300.0       -800.0
#             west virginia              -2.0           0.0        -10.0
#             wisconsin                   2.0           0.0          0.0
#             wyoming                    -2.0         440.0          0.0
#      Q2     vermont                     0.0           0.0          0.0
# 2017 Q1     alabama                     0.0           0.0         10.0
#             arizona                     0.0           0.0          0.0
#             arkansas                    0.0           0.0         40.0
#             california                  1.0      -78000.0       1000.0
#             florida                     0.0       -2000.0       1000.0
#             georgia                     0.0      -11000.0          0.0
#             illinois                    0.0           0.0          0.0
#             kansas                      0.0           0.0          0.0
#             louisiana                   0.0           0.0          0.0
#             massachusetts               0.0           0.0          0.0
#             minnesota                   0.0           0.0          0.0
#             mississippi                 0.0           0.0       -500.0
#             missouri                    0.0           0.0          0.0
#             montana                     0.0           0.0          0.0
#             nebraska                    0.0           0.0          0.0
#             new jersey                  0.0           0.0          0.0
#             new york                    0.0           0.0          0.0
#             north dakota                0.0           0.0          0.0
#             oklahoma                    0.0           0.0        100.0
#             pennsylvania               -1.0           0.0        -20.0
#             texas                       3.0      -18000.0          0.0
#             utah                       -1.0        1000.0          0.0
#             vermont                     0.0           0.0          0.0
#             washington                  0.0           0.0          0.0
#      Q2     arizona                     0.0           0.0          0.0
#             arkansas                   -3.0        1000.0          0.0
#             california                  2.0      -50000.0     -15000.0
#             colorado                    3.0        2500.0          0.0
#             connecticut                 0.0           0.0          0.0
#             florida                     4.0           0.0          0.0
#             georgia                     2.0           0.0      -2000.0
#             hawaii                      0.0        2480.0         10.0
#             idaho                       1.0       -2000.0          0.0
#             illinois                    0.0           0.0          0.0
#             indiana                     0.0           0.0          0.0
#             iowa                        1.0       -1000.0          0.0
#             kansas                     -1.0           0.0        -20.0
#             kentucky                    4.0         200.0        -10.0
#             louisiana                  -1.0        -500.0      -1000.0
#             maine                       1.0         310.0          0.0
#             maryland                    0.0         200.0          0.0
#             massachusetts               0.0        -500.0          0.0
#             michigan                    2.0       -2000.0       2000.0
#             minnesota                   5.0         500.0       -500.0
#             mississippi                 0.0           0.0     -16000.0
#             missouri                    1.0         100.0          0.0
#             montana                     0.0        3000.0      -2000.0
#             nebraska                    2.0        1000.0     -12000.0
#             new jersey                  0.0         300.0          0.0
#             new mexico                  1.0        1000.0          0.0
#             new york                    0.0         500.0          0.0
#             north carolina              6.0        1100.0          0.0
#             north dakota                1.0       11500.0       4000.0
#             ohio                       -1.0       -1000.0          0.0
#             oklahoma                    0.0       -1800.0       -400.0
#             oregon                      0.0       -2500.0      -2000.0
#             other states                0.0           0.0        100.0
#             pennsylvania                0.0         500.0        100.0
#             south carolina              0.0        1100.0          0.0
#             south dakota                4.0           0.0       3000.0
#             tennessee                   2.0           0.0        200.0
#             texas                       3.0           0.0          0.0
#             utah                        2.0       -2000.0       -500.0
#             virginia                    0.0           0.0          0.0
#             washington                  1.0       -6000.0      -1000.0
#             west virginia               0.0         700.0          0.0
#             wisconsin                   2.0           0.0          0.0
#             wyoming                     0.0        1200.0       -600.0
# 2018 Q1     california                  0.0        5000.0        500.0
#             florida                     1.0           0.0          0.0
#             hawaii                     -2.0           0.0       -100.0
#             iowa                        2.0        -150.0          0.0
#             kansas                      0.0        -130.0          0.0
#             kentucky                   -7.0         240.0          0.0
#             maine                       9.0         -20.0          0.0
#             maryland                    1.0         400.0          0.0
#             massachusetts               1.0           0.0          0.0
#             michigan                   -5.0       -6500.0          0.0
#             minnesota                   0.0       -5500.0          0.0
#             north dakota                0.0           0.0          0.0
#             ohio                        3.0           0.0          0.0
#             oregon                      0.0        -500.0          0.0
#             other states               -2.0           0.0          0.0
#             pennsylvania               12.0        -400.0          0.0
#             tennessee                   4.0         -60.0          0.0
#             texas                       3.0        6000.0          0.0
#             vermont                     5.0           0.0          0.0
#             washington                  0.0           0.0         10.0
#             west virginia               5.0           0.0          0.0
#             wisconsin                   0.0           0.0         40.0
#             wyoming                    -1.0           0.0          0.0
#      Q2     alabama                    -2.0         400.0          0.0
#             arizona                     0.0        2000.0          0.0
#             arkansas                    0.0       -1000.0          0.0
#             california                  3.0       -4000.0       1000.0
#             colorado                    2.0        3000.0        130.0
#             florida                     3.0       -5000.0      -1000.0
#             georgia                     1.0        1000.0          0.0
#             hawaii                      0.0          30.0          0.0
#             idaho                       2.0       -2500.0          0.0
#             illinois                    2.0         300.0        100.0
#             indiana                    -1.0           0.0          0.0
#             kansas                      4.0        1700.0          0.0
#             kentucky                    7.0         100.0          0.0
#             louisiana                   1.0       -2100.0          0.0
#             maine                       7.0           0.0        -90.0
#             massachusetts               0.0           0.0          0.0
#             michigan                    2.0        5000.0        500.0
#             minnesota                   1.0       -4000.0       1000.0
#             mississippi                -2.0         100.0        500.0
#             missouri                    0.0         300.0          0.0
#             montana                     0.0       -9000.0       2000.0
#             nebraska                   -2.0         900.0        200.0
#             new jersey                  0.0         100.0          0.0
#             new mexico                  0.0        1410.0          0.0
#             new york                   -3.0        3000.0        100.0
#             north carolina              7.0         500.0          0.0
#             north dakota                2.0       -7000.0      18000.0
#             ohio                        4.0           0.0        300.0
#             oklahoma                    1.0        1500.0          0.0
#             oregon                      0.0       -5500.0          0.0
#             other states                1.0        -130.0        100.0
#             pennsylvania                0.0           0.0          0.0
#             south carolina              0.0         200.0          0.0
#             south dakota                3.0       -8500.0          0.0
#             tennessee                   0.0         600.0          0.0
#             texas                       2.0      -21000.0       2000.0
#             utah                        0.0        -500.0          0.0
#             virginia                   -1.0         200.0          0.0
#             washington                  1.0       -3500.0        100.0
#             west virginia               1.0         200.0          0.0
#             wisconsin                   0.0        -500.0        400.0
#             wyoming                    -2.0        2400.0       -100.0
# 2019 Q1     kansas                      0.0           0.0          0.0
# 2020 Q1     alabama                     1.0         900.0          0.0
#             arizona                     7.0        2850.0          0.0
#             arkansas                    3.0        1100.0          0.0
#             colorado                    1.0        3150.0          0.0
#             connecticut                 1.0         300.0          0.0
#             florida                     0.0           0.0          0.0
#             georgia                     0.0        9000.0          0.0
#             hawaii                      2.0         300.0          0.0
#             idaho                       0.0           0.0          0.0
#             illinois                    5.0        2000.0          0.0
#             indiana                     1.0         620.0          0.0
#             iowa                        1.0        4800.0          0.0
#             kansas                      1.0         800.0          0.0
#             kentucky                    0.0        -100.0          0.0
#             maine                       4.0         460.0          0.0
#             maryland                   18.0        1900.0          0.0
#             massachusetts               3.0         500.0          0.0
#             michigan                    3.0        6200.0          0.0
#             minnesota                   0.0        -700.0          0.0
#             mississippi                 0.0           0.0          0.0
#             missouri                   40.0        3370.0          0.0
#             montana                     0.0         500.0          0.0
#             nebraska                    0.0           0.0          0.0
#             new jersey                  3.0         690.0          0.0
#             new mexico                  0.0           0.0          0.0
#             new york                   -3.0           0.0          0.0
#             north carolina              0.0        -400.0          0.0
#             north dakota                4.0       -2500.0          0.0
#             ohio                        1.0           0.0          0.0
#             oklahoma                    0.0           0.0          0.0
#             oregon                      0.0           0.0          0.0
#             other states                1.0         400.0          0.0
#             pennsylvania                4.0        -730.0          0.0
#             south carolina              3.0        -800.0          0.0
#             south dakota                0.0           0.0          0.0
#             tennessee                   8.0        1200.0          0.0
#             utah                        4.0       -1200.0          0.0
#             vermont                     0.0         500.0          0.0
#             virginia                    0.0           0.0          0.0
#             washington                  0.0           0.0          0.0
#             west virginia               0.0         150.0          0.0
#             wisconsin                   1.0       -1300.0          0.0
#             wyoming                     0.0           0.0          0.0
#      Q2     alabama                     0.0           0.0        -20.0
#             arizona                     0.0         500.0          0.0
#             arkansas                    0.0        -100.0          0.0
#             california                  2.0       -9000.0          0.0
#             colorado                    0.0        1000.0          0.0
#             connecticut                 0.0           0.0        -30.0
#             florida                     1.0      -11000.0      -4500.0
#             georgia                     0.0       -1000.0       1000.0
#             hawaii                      0.0        2760.0          0.0
#             idaho                       4.0      -10000.0          0.0
#             indiana                     0.0         200.0      -1400.0
#             iowa                        0.0        2500.0          0.0
#             kansas                      3.0         100.0          0.0
#             kentucky                    0.0           0.0          0.0
#             louisiana                   0.0         100.0          0.0
#             maine                      -3.0           0.0          0.0
#             maryland                   -1.0        -100.0          0.0
#             massachusetts               0.0        -110.0        -50.0
#             michigan                   -1.0        1500.0          0.0
#             minnesota                   5.0      -11000.0          0.0
#             mississippi                 4.0       -2200.0          0.0
#             missouri                    0.0        -100.0          0.0
#             montana                    -1.0        4000.0       -500.0
#             nebraska                    0.0           0.0          0.0
#             new jersey                 -1.0        -100.0        -70.0
#             new mexico                 16.0         150.0        -20.0
#             new york                   -2.0        -500.0       -500.0
#             north dakota                1.0       24000.0       1000.0
#             oklahoma                    0.0           0.0          0.0
#             oregon                      0.0         500.0          0.0
#             other states                0.0         130.0          0.0
#             pennsylvania               -1.0        -500.0       -200.0
#             south carolina              0.0           0.0          0.0
#             south dakota                0.0        1500.0          0.0
#             tennessee                   0.0           0.0          0.0
#             texas                       3.0      -60000.0          0.0
#             utah                        0.0        1500.0       -500.0
#             vermont                    -1.0         -20.0        -20.0
#             virginia                    0.0           0.0          0.0
#             washington                  0.0           0.0          0.0
#             wisconsin                   0.0        2500.0          0.0
#             wyoming                     0.0        2100.0          0.0
# 2021 Q1     alabama                    -1.0           0.0          0.0
#             arizona                    -1.0        1000.0       4320.0
#             arkansas                   13.0        -100.0          0.0
#             california                  5.0      113000.0          0.0
#             colorado                    0.0         150.0          0.0
#             connecticut                 0.0          50.0          0.0
#             florida                     0.0        5000.0          0.0
#             hawaii                     -1.0        -100.0          0.0
#             idaho                      -1.0        2000.0        500.0
#             illinois                   -1.0        -800.0          0.0
#             indiana                    -1.0       -1100.0          0.0
#             iowa                        0.0       -2000.0          0.0
#             kansas                     -4.0       -1300.0          0.0
#             kentucky                   -3.0       -1500.0          0.0
#             louisiana                  -1.0        2500.0          0.0
#             maryland                    9.0         710.0          0.0
#             massachusetts               0.0           0.0          0.0
#             minnesota                  -1.0       -1600.0          0.0
#             mississippi                 0.0        -500.0      -3730.0
#             missouri                  -11.0        -670.0          0.0
#             montana                     0.0         820.0          0.0
#             nebraska                    0.0        -370.0          0.0
#             new jersey                  0.0         290.0          0.0
#             new mexico                 -2.0       -2030.0          0.0
#             new york                    0.0        -800.0          0.0
#             north carolina              7.0        -800.0          0.0
#             north dakota                0.0           0.0          0.0
#             oregon                      0.0       -1000.0          0.0
#             other states                0.0         150.0          0.0
#             pennsylvania               -3.0       -3000.0          0.0
#             south carolina              1.0           0.0          0.0
#             tennessee                  -1.0        -500.0          0.0
#             texas                       1.0        5000.0        500.0
#             utah                       -1.0       -1300.0          0.0
#             vermont                     0.0          30.0          0.0
#             virginia                   -1.0        -500.0          0.0
#             washington                 -1.0        4000.0          0.0
#             west virginia              -3.0       -1500.0       -260.0
#             wisconsin                  -1.0       -6770.0          0.0
#             wyoming                     3.0        2500.0          0.0
#      Q2     alabama                     0.0         600.0          0.0
#             arizona                     1.0        3500.0      -3800.0
#             arkansas                    0.0           0.0       -500.0
#             california                  5.0      -35000.0          0.0
#             colorado                    9.0        1200.0          0.0
#             connecticut                 0.0         140.0        -60.0
#             florida                     0.0        1000.0          0.0
#             georgia                     1.0           0.0          0.0
#             hawaii                     -1.0          30.0          0.0
#             illinois                    0.0           0.0          0.0
#             indiana                     0.0           0.0          0.0
#             iowa                        0.0         500.0          0.0
#             kansas                     13.0        -100.0          0.0
#             louisiana                   0.0           0.0          0.0
#             maine                       0.0           0.0          0.0
#             maryland                    0.0           0.0          0.0
#             massachusetts              -1.0         600.0          0.0
#             michigan                   -1.0           0.0          0.0
#             minnesota                   0.0        1000.0          0.0
#             mississippi                -1.0         500.0          0.0
#             missouri                    0.0         300.0          0.0
#             montana                     0.0           0.0          0.0
#             nebraska                    0.0         500.0          0.0
#             new jersey                  0.0           0.0          0.0
#             new mexico                  2.0         480.0          0.0
#             new york                    0.0         500.0          0.0
#             north dakota                0.0        6700.0        100.0
#             ohio                        0.0        1500.0          0.0
#             oregon                     -1.0           0.0          0.0
#             other states                0.0         -10.0         30.0
#             pennsylvania                0.0           0.0       -100.0
#             south carolina              0.0         100.0       -100.0
#             south dakota                0.0           0.0          0.0
#             texas                       9.0        2000.0          0.0
#             utah                        1.0        1000.0       -200.0
#             vermont                     0.0           0.0          0.0
#             washington                  0.0           0.0          0.0
#             wisconsin                   0.0        1000.0          0.0
#             wyoming                    -2.0           0.0          0.0
#
# ...
#             texas                             0.0        0.0         0.0
#             utah                             -0.1       -0.1         0.0
#             vermont                           0.8        0.5         0.0
#             washington                        0.0      -10.0         0.0
#             wisconsin                         1.5        0.1        -7.2
#             wyoming                           0.0        0.0         0.0
#
#                             Other  Unknown
# year months state
# 2016 Q1     alabama           0.0      0.0
#             arizona           0.0      0.0
#             arkansas          0.0      0.0
#             california        0.0      0.1
#             colorado         -0.3      0.0
#             florida          -0.1     -0.1
#             georgia           0.1      0.0
#             hawaii            0.0      0.0
#             idaho            -0.1      1.1
#             illinois         -0.4     -1.8
#             indiana           0.0      0.0
#             iowa            -10.4     -7.4
#             kansas           -0.2     -0.4
#             kentucky          1.4      0.9
#             louisiana         2.5      0.4
#             maryland         -1.1     -0.1
#             massachusetts     0.0      0.0
#             michigan          0.1      1.0
#             minnesota         0.9      0.3
#             mississippi       0.1      5.7
#             missouri          0.5      1.9
#             montana          -0.1     -0.1
#             nebraska          0.0      0.2
#             new jersey        0.5      3.8
#             new mexico        0.0      0.0
#             new york          0.0      0.0
#             north carolina    0.0     -0.1
#             north dakota      0.1      1.8
#             ohio              0.0      0.0
#             oklahoma         -1.5    -20.5
#             oregon            0.0      0.0
#             other states     -4.7      0.1
#             pennsylvania      0.0      0.0
#             south carolina    0.0     -0.1
#             south dakota      0.1      0.0
#             tennessee         0.0      0.0
#             texas            -0.3     -0.2
#             utah             -0.3     -0.1
#             vermont           0.0      0.0
#             virginia          0.0      0.0
#             washington        0.2     -0.3
#             west virginia     0.0      0.0
#             wisconsin         2.0      1.0
#             wyoming          -0.2     -0.3
#      Q2     vermont           0.0      0.0
# 2017 Q1     alabama          -0.8     -1.1
#             arizona           0.0      0.0
#             arkansas         -0.6      0.4
#             california        0.0      0.0
#             florida           0.0      0.0
#             georgia           0.0      0.0
#             illinois         -0.3      0.1
#             kansas            0.0      0.0
#             louisiana        -0.9     -0.5
#             massachusetts     0.0      0.4
#             minnesota         0.2      0.0
#             mississippi       0.0      0.0
#             missouri          0.0     -0.1
#             montana           0.4      0.0
#             nebraska         -0.1      0.0
#             new jersey        0.0      0.0
#             new york          0.0     -0.1
#             north dakota      0.0      0.1
#             oklahoma          0.0      0.0
#             pennsylvania      0.0     -0.1
#             texas             0.0      0.0
#             utah              0.0      0.0
#             vermont           0.0      0.1
#             washington       -0.1      0.0
#      Q2     arizona           0.3      0.0
#             arkansas         -0.7     -0.6
#             california        0.1      0.4
#             colorado         -0.1      0.0
#             connecticut      -0.1      0.0
#             florida           0.1      0.3
#             georgia           0.2      0.0
#             hawaii            0.0      0.0
#             idaho             0.1      0.1
#             illinois          0.1      0.1
#             indiana           0.0     -0.1
#             iowa             -0.1      0.0
#             kansas           -0.1     -1.4
#             kentucky         -0.5      2.8
#             louisiana        -0.1      0.0
#             maine             0.4      0.6
#             maryland          0.1      0.1
#             massachusetts     0.0      0.0
#             michigan         -0.1     -0.1
#             minnesota         0.0      0.0
#             mississippi       0.8      0.3
#             missouri          0.0      0.1
#             montana           0.0      0.0
#             nebraska          7.1      0.3
#             new jersey        0.0      0.1
#             new mexico        0.0      0.0
#             new york         -0.2      0.0
#             north carolina    0.0      0.0
#             north dakota      0.2      0.6
#             ohio             -0.2      0.0
#             oklahoma          0.1      0.1
#             oregon            1.0      1.7
#             other states     -0.1      0.0
#             pennsylvania      0.0     -0.1
#             south carolina    0.0      0.1
#             south dakota     -1.2      0.0
#             tennessee         0.2      0.0
#             texas            -0.1      0.3
#             utah              1.7      0.0
#             virginia         -0.1      0.0
#             washington        0.5      0.0
#             west virginia     0.1      0.0
#             wisconsin         0.7      0.0
#             wyoming          -1.7     -0.2
# 2018 Q1     california        0.0      0.0
#             florida           0.0      0.0
#             hawaii            0.0     -0.1
#             iowa              0.0      0.0
#             kansas            0.0      0.0
#             kentucky          0.0      0.0
#             maine             0.0      0.0
#             maryland          0.0      0.0
#             massachusetts     0.3      0.2
#             michigan          0.0      0.0
#             minnesota         0.0      0.0
#             north dakota     -0.1      0.0
#             ohio              0.0      0.0
#             oregon            0.0      0.0
#             other states     -0.1     -0.1
#             pennsylvania      0.0      0.0
#             tennessee         0.0      0.0
#             texas             0.0      0.0
#             vermont           0.0      0.0
#             washington        0.0      0.0
#             west virginia     0.0      0.0
#             wisconsin         0.0      0.0
#             wyoming          -0.2     -0.1
#      Q2     alabama          -2.1      0.0
#             arizona          -0.2      0.4
#             arkansas          5.6     -3.4
#             california       -0.1     -0.1
#             colorado         -0.1      0.1
#             florida           0.0      0.0
#             georgia          -0.2      0.5
#             hawaii            0.6      0.0
#             idaho             0.1      0.3
#             illinois          0.0      0.0
#             indiana           0.0      0.0
#             kansas            0.0      0.0
#             kentucky          0.4     -0.4
#             louisiana         0.0      0.0
#             maine            -0.1     -0.1
#             massachusetts     0.0      0.0
#             michigan         -0.2     -0.2
#             minnesota         0.2     -1.0
#             mississippi      -1.6      0.1
#             missouri          0.0      0.0
#             montana          -0.1      0.4
#             nebraska          1.5      1.5
#             new jersey        0.0      0.0
#             new mexico        0.0      0.0
#             new york         -0.6      0.1
#             north carolina    0.0      0.0
#             north dakota      1.0      0.0
#             ohio             -0.1     -0.1
#             oklahoma          0.0      0.0
#             oregon            0.1      0.0
#             other states     -0.4     -0.1
#             pennsylvania      0.0      0.0
#             south carolina    0.2      0.1
#             south dakota     -1.9      0.0
#             tennessee         0.0      0.0
#             texas             0.2      0.3
#             utah              0.0      0.0
#             virginia         -0.2      0.0
#             washington        0.0      0.0
#             west virginia     0.0      0.0
#             wisconsin         0.4     -0.1
#             wyoming          -0.2     -0.5
# 2019 Q1     kansas            0.0      0.0
# 2020 Q1     alabama           0.0      0.0
#             arizona           0.0      0.0
#             arkansas         -0.4      0.0
#             colorado          0.0      0.0
#             connecticut       0.0      0.0
#             florida           0.0      0.0
#             georgia          -0.4      0.0
#             hawaii           -0.2     -0.2
#             idaho             0.0      0.0
#             illinois          0.0      0.0
#             indiana           0.0      0.0
#             iowa              0.0      0.0
#             kansas            0.0      0.0
#             kentucky          0.0      0.0
#             maine             0.0      0.0
#             maryland          0.0      0.0
#             massachusetts     0.0      0.0
#             michigan         -0.4      0.0
#             minnesota         0.0     -0.3
#             mississippi       0.0      0.0
#             missouri          0.0      0.0
#             montana           0.0      0.0
#             nebraska         -0.3      0.0
#             new jersey        0.0      0.0
#             new mexico        0.0     -0.2
#             new york          0.0      0.0
#             north carolina    0.0      0.0
#             north dakota      0.0      0.0
#             ohio              0.0      0.0
#             oklahoma         -0.4     -0.3
#             oregon            0.0     -0.3
#             other states      0.1     -0.4
#             pennsylvania      0.0      0.0
#             south carolina    0.0      0.0
#             south dakota     -0.3     -0.3
#             tennessee         0.0      0.0
#             utah              0.0      0.0
#             vermont           0.0      0.0
#             virginia          0.0      0.0
#             washington       -0.2     -0.3
#             west virginia     0.0     -0.3
#             wisconsin         0.0      0.0
#             wyoming           0.0      0.0
#      Q2     alabama           0.0      0.0
#             arizona           0.0      0.0
#             arkansas          0.0      0.0
#             california        0.1      0.1
#             colorado          0.0      0.0
#             connecticut       0.0      0.0
#             florida           0.4      0.4
#             georgia          -0.2     -0.4
#             hawaii            0.0      0.0
#             idaho             0.0      0.0
#             indiana           0.0      0.0
#             iowa              0.0      0.0
#             kansas            0.0      0.0
#             kentucky          0.0      0.0
#             louisiana         0.0      0.0
#             maine             0.0      0.0
#             maryland          0.0      0.0
#             massachusetts     0.0     -0.4
#             michigan          0.0      0.0
#             minnesota         0.0     -0.4
#             mississippi       0.1     -0.2
#             missouri          0.0      0.0
#             montana           0.0     -0.3
#             nebraska         -0.1      0.1
#             new jersey       -0.6     -0.1
#             new mexico       -0.4     -0.1
#             new york         -0.1     -0.1
#             north dakota      0.1      0.4
#             oklahoma         -3.0      0.0
#             oregon            0.0      0.0
#             other states     -0.3     -0.3
#             pennsylvania     -0.1      0.0
#             south carolina    0.4      0.1
#             south dakota     15.0      0.0
#             tennessee         0.0      0.0
#             texas             0.0      0.0
#             utah             -0.1      0.0
#             vermont           0.0      0.0
#             virginia          0.0      0.0
#             washington        0.0     -0.4
#             wisconsin         0.0      0.0
#             wyoming           0.0      0.0
# 2021 Q1     alabama           0.0      0.0
#             arizona           0.0     -0.4
#             arkansas          0.0     -0.1
#             california        0.0      0.0
#             colorado         -0.1     -0.8
#             connecticut       0.0      0.0
#             florida           0.0      0.0
#             hawaii            0.0      0.0
#             idaho            -0.2     -0.2
#             illinois          0.0      0.0
#             indiana           0.0     -0.1
#             iowa              0.0      0.0
#             kansas            0.0      0.0
#             kentucky          0.0      0.0
#             louisiana         1.8      0.2
#             maryland          0.0      0.0
#             massachusetts     0.0      0.0
#             minnesota         0.0      0.0
#             mississippi       4.9      0.0
#             missouri          0.0     -5.0
#             montana           0.0      0.0
#             nebraska          0.0      0.0
#             new jersey        0.0      0.0
#             new mexico        0.0      0.0
#             new york          0.0      0.0
#             north carolina    0.0      0.0
#             north dakota      1.5      0.0
#             oregon            0.0      0.0
#             other states     -0.2      0.0
#             pennsylvania      0.0      0.4
#             south carolina    0.0      0.0
#             tennessee         0.0      0.0
#             texas            -0.3      0.0
#             utah              0.0     -4.9
#             vermont           0.0      0.0
#             virginia          0.0      0.0
#             washington       -0.8      0.0
#             west virginia     0.0     -0.2
#             wisconsin         0.0      0.0
#             wyoming           0.0      0.0
#      Q2     alabama           0.0    -18.6
#             arizona           0.0      0.0
#             arkansas         -0.1     -0.1
#             california        0.0      0.0
#             colorado          0.5     -0.4
#             connecticut      -0.2      0.0
#             florida           0.1      0.0
#             georgia           0.0      0.0
#             hawaii            0.0      0.0
#             illinois          1.3      2.2
#             indiana          -1.4     -0.3
#             iowa              1.3      0.0
#             kansas            0.0      0.0
#             louisiana        -9.7      0.0
#             maine             0.0      0.0
#             maryland          0.0      0.0
#             massachusetts    -0.5      0.0
#             michigan         -0.1      0.0
#             minnesota         0.0      0.1
#             mississippi       0.0      0.0
#             missouri          2.5      0.2
#             montana           0.0      0.0
#             nebraska          0.0      0.0
#             new jersey        0.1      0.0
#             new mexico        0.0      0.0
#             new york          0.0      0.0
#             north dakota      0.0      0.0
#             ohio             -0.6     -0.3
#             oregon            0.0      0.0
#             other states     -0.2     -0.3
#             pennsylvania      0.0      0.0
#             south carolina   -0.3     -0.1
#             south dakota    -22.2     -0.1
#             texas             0.0      0.0
#             utah              0.0      0.0
#             vermont           1.0      0.0
#             washington        0.0      0.0
#             wisconsin         0.1      0.2
#             wyoming           0.0      0.0

# %%
'''
Old code

print(df_new.index.shape)
print(df_years_new.index.shape)
#check differences between indices
list_indices1 = df_new.index.tolist()
list_indices2 = df_years_new.index.tolist()
diff_list = sorted(list(set(list_indices2) - set(list_indices1)))# key=lambda tup: tup[1])
print(diff_list)
df_years_new = df_years_new.drop(diff_list)

df_new = df_new.applymap(lambda x: x.replace(",",""))
df_new = df_new.applymap(lambda x: x.replace("(Z)","0"))
df_new = df_new.applymap(lambda x: x.replace("-","0"))
df_new = df_new.fillna(0)
df_years_new = df_years_new.fillna(0)

df_new = df_new.astype("int")
df_years_new = df_years_new.astype("int")
df_diff = df_new - df_years_new
df_diff.mean(),df_diff.std()
'''

# %% [markdown]
# **Let's check that the differences between the values of the two datasets were not due to some values that were set to zero in one dataframe and not in the other one**

# %%
indices = df_diff[df_diff.values != 0].index
df_new_subset = df_new.loc[indices,:]
print(df_new_subset[df_new_subset == 0].count(axis=0)/len(df.index))
# Out:
# cols
# colony_n                 0.000000
# colony_max               0.000000
# colony_lost              0.001449
# colony_lost_pct          0.006522
# colony_added             0.005797
# colony_reno              0.107246
# colony_reno_pct          0.231884
# Varroa mites             0.006522
# Other pests/parasites    0.121014
# Disesases                0.318116
# Pesticides               0.309420
# Other                    0.071014
# Unknown                  0.175362
# dtype: float64

# %%
df_years_new_subset = df_new.loc[indices,:]
print(df_years_new_subset[df_years_new_subset == 0].count(axis=0)/len(df.index))
# Out:
# colony_n                 0.000000
# colony_max               0.000000
# colony_lost              0.001449
# colony_lost_pct          0.006522
# colony_added             0.005797
# colony_reno              0.107246
# colony_reno_pct          0.231884
# Varroa mites             0.006522
# Other pests/parasites    0.121014
# Disesases                0.318116
# Pesticides               0.309420
# Other                    0.071014
# Unknown                  0.175362
# dtype: float64

# %%
#this loop prints the values of df_years_new for each column where df_new in that column is equal to zero.
#If the corresponding values in df_years_new are not equal to zero, means that there are cases where df_new had
#NaN values (then set to zero) while df_years_new did not have.
indices_new = indices.unique()
for col in df_new.columns:
    print(df_years_new.loc[indices_new,col][(df_new.loc[indices_new, col] == 0).values]) #"{}: ".format(col)

#vice versa:
'''
for col in df_new.columns:
    print(df_new.loc[indices_new,col][(df_years_new.loc[indices_new, col] == 0).values]) #"{}: ".format(col)
'''
# Out:
# Series([], Name: colony_n, dtype: float64)
# Series([], Name: colony_max, dtype: float64)
# year  months  state
# 2020  Q2      hawaii    40.0
# Name: colony_lost, dtype: float64
# year  months  state
# 2016  Q2      vermont         0.0
# 2020  Q1      montana         0.0
#       Q2      hawaii          0.0
# 2021  Q1      north dakota    0.0
# Name: colony_lost_pct, dtype: float64
# year  months  state
# 2016  Q1      vermont             0.0
#               west virginia       0.0
# 2017  Q1      vermont             0.0
# 2020  Q1      north dakota     2500.0
# Name: colony_added, dtype: float64
# year  months  state
# 2016  Q1      indiana           0.0
#               iowa              0.0
#               minnesota        10.0
#               montana           0.0
#               nebraska         30.0
#               north dakota      0.0
#               other states     10.0
#               south dakota      0.0
#               vermont           0.0
#               west virginia    10.0
#               wisconsin         0.0
#               wyoming           0.0
# 2017  Q1      arizona           0.0
#               minnesota         0.0
#               nebraska          0.0
#               new jersey        0.0
#               new york          0.0
#               vermont           0.0
#               washington        0.0
# 2018  Q1      vermont           0.0
#               wyoming           0.0
# 2020  Q1      connecticut       0.0
#               maine             0.0
#               missouri          0.0
#               montana           0.0
#               nebraska          0.0
#               new mexico        0.0
#               north dakota      0.0
#               oklahoma          0.0
#               south dakota      0.0
#               utah              0.0
# 2021  Q1      nebraska          0.0
#               new mexico        0.0
#               north dakota      0.0
#               utah              0.0
# Name: colony_reno, dtype: float64
# year  months  state
# 2016  Q1      colorado           0.0
#               illinois           0.0
#               indiana            0.0
#               iowa               0.0
#               maryland           0.0
#               michigan           0.0
#               minnesota          0.0
#               montana            0.0
#               nebraska           0.0
#               new jersey         1.0
#               north dakota       0.0
#               ohio               1.0
#               other states       0.0
#               south dakota       0.0
#               utah               1.0
#               vermont            0.0
#               west virginia      0.0
#               wisconsin          0.0
#               wyoming            0.0
# 2017  Q1      arizona            0.0
#               minnesota          0.0
#               missouri           0.0
#               nebraska           0.0
#               new jersey         0.0
#               new york           0.0
#               north dakota       0.0
#               utah               0.0
#               vermont            0.0
#               washington         0.0
# 2018  Q1      iowa               0.0
#               kentucky           0.0
#               north dakota       0.0
#               vermont            0.0
#               wyoming            0.0
# 2020  Q1      arizona            0.0
#               arkansas           0.0
#               connecticut        0.0
#               maine              0.0
#               maryland           0.0
#               michigan           0.0
#               minnesota          0.0
#               missouri           0.0
#               montana            0.0
#               nebraska           0.0
#               new mexico         0.0
#               north dakota       0.0
#               oklahoma           0.0
#               other states       0.0
#               south dakota       0.0
#               utah               0.0
#               washington         0.0
#               wyoming            0.0
# 2021  Q1      colorado           0.0
#               indiana            0.0
#               iowa               0.0
#               kansas             0.0
#               minnesota          0.0
#               mississippi       11.0
#               montana            0.0
#               nebraska           0.0
#               new mexico         0.0
#               north carolina     1.0
#               north dakota       0.0
#               pennsylvania       0.0
#               utah               0.0
#               wisconsin          0.0
# Name: colony_reno_pct, dtype: float64
# year  months  state
# 2016  Q1      wyoming    0.0
# 2020  Q1      wyoming    0.2
# Name: Varroa mites, dtype: float64
# year  months  state
# 2016  Q1      montana         0.0
#               north dakota    0.0
#               south dakota    0.0
#               vermont         0.0
# 2017  Q1      north dakota    0.0
#               utah            0.0
# 2018  Q2      colorado        0.0
# 2020  Q1      arizona         0.1
#               colorado        0.0
#               minnesota       0.0
#               montana         0.0
#               nebraska        0.1
#               new mexico      0.0
#               north dakota    0.0
#               other states    0.0
#               south dakota    0.1
#               washington      0.1
#               wyoming         0.1
#       Q2      arizona         0.0
#               colorado        0.1
#               maine           0.2
#               new mexico      0.4
#               utah            0.0
#               washington      0.0
#               wyoming         0.0
# 2021  Q1      colorado        0.0
#               montana         0.0
#               nebraska        0.0
#               new mexico      0.1
#               vermont         0.0
#               wisconsin       0.0
#               wyoming         0.0
#       Q2      arizona         0.0
#               colorado        0.0
#               maine           0.0
#               minnesota       0.0
#               montana         0.0
#               nebraska        0.0
#               other states    0.0
# Name: Other pests/parasites, dtype: float64
# year  months  state
# 2016  Q1      arizona           0.0
#               arkansas          0.0
#               hawaii            0.0
#               maryland          0.0
#               michigan          0.0
#               mississippi       0.0
#               montana           0.0
#               north dakota      0.0
#               oklahoma          0.1
#               south dakota      0.0
#               virginia          0.0
# 2017  Q1      kansas            0.0
#               mississippi       0.0
#               montana           0.0
#               north dakota      0.0
#               oklahoma          0.0
#               washington        0.0
#       Q2      connecticut       0.0
#               hawaii            0.0
#               louisiana         0.0
#               mississippi       0.0
# 2018  Q2      mississippi       0.0
#               new jersey        0.0
# 2020  Q1      alabama           0.0
#               arizona           0.1
#               arkansas          0.2
#               colorado          0.1
#               connecticut       0.4
#               georgia           0.2
#               hawaii            0.1
#               idaho             0.1
#               illinois          0.2
#               indiana           0.1
#               iowa              0.0
#               maryland          0.1
#               michigan          0.2
#               minnesota         0.0
#               mississippi       0.3
#               montana           0.0
#               nebraska          0.1
#               new mexico        0.0
#               new york          0.0
#               north dakota      0.0
#               oklahoma          0.4
#               other states      0.0
#               south dakota      0.0
#               virginia          0.3
#               washington        0.1
#               wisconsin         0.4
#       Q2      arizona           0.0
#               colorado          0.1
#               connecticut       0.0
#               kentucky          0.2
#               massachusetts     0.3
#               mississippi       0.0
#               new mexico        0.3
#               oklahoma          0.4
#               tennessee         0.2
#               utah              0.3
#               virginia          0.3
# 2021  Q1      alabama           0.0
#               arkansas          0.0
#               colorado          0.0
#               connecticut       0.0
#               hawaii            0.0
#               idaho             0.0
#               indiana           0.0
#               iowa              0.0
#               kansas            0.0
#               kentucky          0.0
#               louisiana         0.0
#               maryland          0.0
#               minnesota         0.0
#               mississippi       0.0
#               missouri          0.0
#               montana           0.0
#               nebraska          0.0
#               new mexico        0.0
#               north carolina    0.0
#               pennsylvania      0.0
#               south carolina    0.0
#               utah              0.0
#               virginia          0.0
#               wisconsin         0.0
#               wyoming           0.0
#       Q2      colorado          0.0
#               hawaii            0.0
#               louisiana         0.0
#               maine             0.0
#               maryland          0.0
#               massachusetts     0.0
#               minnesota         0.0
#               nebraska          0.0
#               new jersey        0.0
#               north dakota      0.0
#               other states      0.0
#               texas             0.0
#               wyoming           0.0
# Name: Disesases, dtype: float64
# year  months  state
# 2016  Q1      massachusetts     0.0
#               new mexico        0.0
#               north dakota      0.0
#               oregon            0.0
#               south dakota      0.0
#               vermont           0.0
#       Q2      vermont           0.0
# 2017  Q1      nebraska          0.0
#               north dakota      0.0
#               utah              0.0
#               washington        0.0
#       Q2      hawaii            0.0
#               new mexico        0.0
#               other states      0.0
# 2018  Q1      hawaii            0.0
#               maine             0.0
#               north dakota      0.0
#               other states      0.0
#               wyoming           0.0
#       Q2      hawaii            0.0
#               new mexico        0.0
#               other states      0.0
# 2020  Q1      arizona           0.0
#               colorado          0.4
#               connecticut       0.0
#               georgia           0.3
#               hawaii            0.0
#               illinois          0.0
#               iowa              0.2
#               kentucky          0.3
#               maine             0.0
#               maryland          0.0
#               massachusetts     0.3
#               michigan          0.2
#               minnesota         0.2
#               montana           0.0
#               nebraska          0.0
#               new jersey        0.1
#               new mexico        0.0
#               new york          0.0
#               north dakota      0.0
#               ohio              0.1
#               other states      0.0
#               south carolina    0.3
#               tennessee         0.0
#               virginia          0.3
#               wisconsin         0.0
#               wyoming           0.0
#       Q2      colorado          0.0
#               connecticut       0.0
#               hawaii            0.0
#               louisiana         0.1
#               maine             0.0
#               massachusetts     0.4
#               montana           0.0
#               new jersey        0.1
#               new mexico        0.4
#               new york          0.2
#               other states      0.0
#               pennsylvania      0.3
#               south carolina    0.0
#               south dakota      0.4
#               vermont           0.0
#               virginia          0.4
# 2021  Q1      alabama           0.0
#               arizona           0.0
#               colorado          0.0
#               hawaii            0.0
#               kansas            0.0
#               kentucky          0.0
#               maryland          0.0
#               montana           0.0
#               new mexico        0.0
#               north carolina    0.0
#               north dakota      0.0
#               oregon            0.0
#               other states      0.0
#               pennsylvania      0.0
#               vermont           0.0
#               washington        0.0
#               wisconsin         0.0
#               wyoming           0.0
#       Q2      colorado          0.0
#               connecticut       0.0
#               hawaii            0.0
#               louisiana         0.0
#               maine             0.0
#               north dakota      0.0
#               south carolina    0.0
#               vermont           0.0
# Name: Pesticides, dtype: float64
# year  months  state
# 2020  Q1      arkansas         0.4
#               georgia          0.4
#               hawaii           0.2
#               michigan         0.4
#               nebraska         0.3
#               oklahoma         0.4
#               south dakota     0.3
#               washington       0.2
#       Q2      nebraska         0.1
#               new mexico       0.4
#               other states     0.3
#               utah             0.1
# 2021  Q1      montana          0.0
#       Q2      hawaii           0.0
#               massachusetts    0.5
#               new mexico       0.0
#               utah             0.0
# Name: Other, dtype: float64
# year  months  state
# 2016  Q1      hawaii           0.0
#               montana          0.1
# 2017  Q2      hawaii           0.0
#               utah             0.0
# 2018  Q1      hawaii           0.1
#               north dakota     0.0
#       Q2      maine            0.1
#               south dakota     0.0
# 2020  Q1      hawaii           0.2
#               minnesota        0.3
#               montana          0.0
#               new mexico       0.2
#               north dakota     0.0
#               oklahoma         0.3
#               oregon           0.3
#               other states     0.4
#               south dakota     0.3
#               washington       0.3
#               west virginia    0.3
#       Q2      hawaii           0.0
#               maine            0.0
#               massachusetts    0.4
#               minnesota        0.4
#               mississippi      0.2
#               montana          0.3
#               new jersey       0.1
#               new mexico       0.1
#               other states     0.3
#               vermont          0.0
#               washington       0.4
# 2021  Q1      hawaii           0.0
#               minnesota        0.0
#               montana          0.0
#               north dakota     0.0
#               texas            0.0
#               vermont          0.0
#               washington       0.0
#       Q2      connecticut      0.0
#               hawaii           0.0
#               maine            0.0
#               massachusetts    0.0
#               michigan         0.0
#               new mexico       0.0
#               north dakota     0.0
#               texas            0.0
#               vermont          0.0
#               washington       0.0
# Name: Unknown, dtype: float64

# %%
print(df_new.loc[(2020, "Q2", "hawaii"), "colony_lost"])
print(df_years_new.loc[(2020, "Q2", "hawaii"), "colony_lost"])
# Out:
# 0.0
# 40.0

# %% [markdown]
# **Conclusion**: In both the dataframes there are values which are equal to zero in one but not in the other one. <br>
# This might represent an issue since each dataframe had different NaN values with respect to the other one which were then set to zero. <br>
# **Problem**: I can't check the indices of NaN values for df_new dataframe since it was preprocessed removing the NaN values before importing it.

# %% [markdown]
# Check the differences between df_US and the new data for US

# %%
df_US.head()
# Out:
#      year months   colony_n  colony_max  colony_lost  colony_lost_pct  \
# 46   2015     Q1  2824610.0         NaN     500020.0             18.0
# 93   2015     Q2  2849500.0         NaN     352860.0             12.0
# 140  2015     Q3  3132880.0         NaN     457100.0             15.0
# 187  2015     Q4  2874760.0         NaN     412380.0             14.0
# 234  2016     Q1  2594590.0         NaN     428800.0             17.0
#
#      colony_added  colony_reno  colony_reno_pct  Varroa mites  \
# 46       546980.0     270530.0             10.0          25.2
# 93       661860.0     692850.0             24.0          43.4
# 140      172990.0     303070.0             10.0          41.2
# 187      117150.0     158790.0              6.0          37.0
# 234      378160.0     158050.0              6.0          34.3
#
#      Other pests/parasites  Disesases  Pesticides  Other  Unknown
# 46                     8.6        3.1         7.4    6.9      4.3
# 93                    19.5        4.9        16.6   11.6      3.5
# 140                   17.6        8.0        15.2    8.8      4.8
# 187                   11.4        5.2         9.5    7.3      6.9
# 234                   12.6        6.2        10.5    7.0      5.4

# %%
df_US_new.head()
# Out:
#               colony_n  colony_lost  colony_added  colony_end  \
# year months
# 2015 Q1      2824610.0     500020.0        546980   2849500.0
#      Q2      2849500.0     352860.0        661860   3132880.0
#      Q3      3132880.0     457100.0        172990   2874760.0
#      Q4      2874760.0     412380.0        117150   2619940.0
# 2016 Q1      2619940.0     416100.0        571880   2801470.0
#
#              colony_end_computed  diff_without_reno  diff_without_reno_pct
# year months
# 2015 Q1                2871570.0            22070.0               0.774522
#      Q2                3158500.0            25620.0               0.817778
#      Q3                2848770.0           -25990.0              -0.904075
#      Q4                2579530.0           -40410.0              -1.542402
# 2016 Q1                2775720.0           -25750.0              -0.919160

# %%
df_US_diff = df_US.groupby(["year", "months"]).sum()[["colony_n", "colony_lost", "colony_added"]] - df_US_new[["colony_n", "colony_lost", "colony_added"]]
df_US_diff[(df_US_diff != 0).any(axis=1)]
# Out:
#              colony_n  colony_lost  colony_added
# year months
# 2016 Q1      -25350.0      12700.0     -193720.0
# 2017 Q1      -25500.0     -36800.0      108000.0
#      Q2      191880.0     -59910.0       40110.0
# 2018 Q1       -4000.0     -12810.0        1620.0
#      Q2       26780.0     -85270.0       49290.0
# 2019 Q2           NaN          NaN           NaN
# 2020 Q1           0.0     -15540.0      -33960.0
#      Q2       10900.0     -48360.0       60690.0
# 2021 Q1       20000.0     -92010.0     -108960.0
#      Q2       25550.0     -96420.0       11960.0

# %% [markdown]
# ## Check the datapoint correctness and coherency in USDA dataset

# %% [markdown]
# **Reference**: <br>
# The questionnaire can be viewed here: https://www.nass.usda.gov/Publications/Methodology_and_Data_Quality/Honey_Bee_Colonies/08_2022/July%202022%20QCL.pdf <br>
# That is a link to the questionnaire for the July quarter. Similar questionnaires are used in October and then the following January and April, with the only difference being the year and month used in the questions.
#
# Max colonies is calculated in the summary. While some colonies in the U.S. are primarily honey producing colonies and usually remain in one state, other colonies are primarily used for pollination purposes. Pollinating colonies are moved from state to state throughout the year following the crops that need to be pollinated. Therefore, the maximum number of colonies in a state can vary widely during a quarter and throughout the year. For example, on an individual record level an operation could not have any colonies in North Dakota at the beginning of a quarter because all of their colonies are in California for almond pollination. But during the middle of the quarter the almond pollination season ends and the colonies are moved back to North Dakota. So while the January 1 colony number might be zero, the max colony number during the January – March quarter could be 1,000.
#
# The record level data is processed in a summary which also deals with non-response through a weighting procedure and the state level indications are created.
#
# Colonies renovated are not included in the calculation for the next quarter’s starting inventory.
#
# As you can see on the questionnaire linked above, beginning and ending inventory is asked on the survey. Ending inventory is generally considered one of the stronger indications due to memory bias of remembering facts from three months ago and what happened during those three months.
#
# At the state level the calculation is as follows: Max colonies – Lost Colonies + Added Colonies  = Beginning Inventory of next quarter, assuming no colonies were moved out of state. However, because colonies can move out of state before the start of the next quarter, it means that the starting inventory can be much lower. If no colonies are moved out of state, then the calculation above should be within 2% of the starting inventory of the following quarter. At the national level, the maximum colony value is not calculated as colonies are not sent across borders for pollinating. Therefore the calculation is First of the Quarter Inventory – Lost + Added = (+/-1%) Beginning Inventory.

# %% [markdown]
# ## USA data

# %%
df_US_new = df_new[["colony_n", "colony_lost", "colony_added"]]
df_US_new["colony_n"].reset_index()
df_US_new = df_US_new.groupby(["year", "months"]).sum()

# %%
df_US_new.head()
# Out:
#               colony_n  colony_lost  colony_added
# year months
# 2015 Q1      2824610.0     500020.0        546980
#      Q2      2849500.0     352860.0        661860
#      Q3      3132880.0     457100.0        172990
#      Q4      2874760.0     412380.0        117150
# 2016 Q1      2619940.0     416100.0        571880

# %%
df_US_new["colony_end"] = df_US_new["colony_n"].shift(-1)
df_US_new["colony_end_computed"] = df_US_new["colony_n"] + df_US_new["colony_added"] - df_US_new["colony_lost"]
df_US_new["diff_without_reno"] = df_US_new["colony_end_computed"]-df_US_new["colony_end"]
df_US_new["diff_without_reno_pct"] = df_US_new["diff_without_reno"]*100/df_US_new["colony_end"]
df_US_new.loc[(2019,"Q1"), ["diff_without_reno", "diff_without_reno_pct"]] = [0,0]
df_US_new
# Out:
#               colony_n  colony_lost  colony_added  colony_end  \
# year months
# 2015 Q1      2824610.0     500020.0        546980   2849500.0
#      Q2      2849500.0     352860.0        661860   3132880.0
#      Q3      3132880.0     457100.0        172990   2874760.0
#      Q4      2874760.0     412380.0        117150   2619940.0
# 2016 Q1      2619940.0     416100.0        571880   2801470.0
#      Q2      2801470.0     329820.0        736920   3181180.0
#      Q3      3181180.0     397290.0        217320   3032060.0
#      Q4      3032060.0     502350.0        124660   2641090.0
# 2017 Q1      2641090.0     398650.0        478240   2694150.0
#      Q2      2694150.0     285590.0        613360   2994500.0
#      Q3      2994500.0     394810.0        284370   2849770.0
#      Q4      2849770.0     424860.0        204510   2635220.0
# 2018 Q1      2635220.0     438030.0        511320   2665880.0
#      Q2      2665880.0     355270.0        676360   2958790.0
#      Q3      2958790.0     377120.0        263560   2868970.0
#      Q4      2868970.0     444730.0        219640   2671470.0
# 2019 Q1      2671470.0     407700.0        247710   3175960.0
#      Q3      3175960.0     434700.0        252550   3018110.0
#      Q4      3018110.0     399510.0        233260   2876100.0
# 2020 Q1      2876100.0     415110.0        511160   2972000.0
#      Q2      2972000.0     300990.0        536170   3175330.0
#      Q3      3175330.0     411490.0        348280   3135340.0
#      Q4      3135340.0     484920.0        271500   2903240.0
# 2021 Q1      2903240.0     464640.0        417490   2829520.0
#      Q2      2829520.0     352280.0        665730   3173390.0
#      Q3      3173390.0     295660.0        194900   3091790.0
#      Q4      3091790.0     329110.0         93940   2875770.0
# 2022 Q1      2875770.0     331780.0        367890   2921590.0
#      Q2      2921590.0     282630.0        589630         NaN
#
#              colony_end_computed  diff_without_reno  diff_without_reno_pct
# year months
# 2015 Q1                2871570.0            22070.0               0.774522
#      Q2                3158500.0            25620.0               0.817778
#      Q3                2848770.0           -25990.0              -0.904075
#      Q4                2579530.0           -40410.0              -1.542402
# 2016 Q1                2775720.0           -25750.0              -0.919160
#      Q2                3208570.0            27390.0               0.861001
#      Q3                3001210.0           -30850.0              -1.017460
#      Q4                2654370.0            13280.0               0.502823
# 2017 Q1                2720680.0            26530.0               0.984726
#      Q2                3021920.0            27420.0               0.915679
#      Q3                2884060.0            34290.0               1.203255
#      Q4                2629420.0            -5800.0              -0.220095
# 2018 Q1                2708510.0            42630.0               1.599097
#      Q2                2986970.0            28180.0               0.952416
#      Q3                2845230.0           -23740.0              -0.827475
#      Q4                2643880.0           -27590.0              -1.032765
# 2019 Q1                2511480.0                0.0               0.000000
#      Q3                2993810.0           -24300.0              -0.805140
#      Q4                2851860.0           -24240.0              -0.842808
# 2020 Q1                2972150.0              150.0               0.005047
#      Q2                3207180.0            31850.0               1.003045
#      Q3                3112120.0           -23220.0              -0.740590
#      Q4                2921920.0            18680.0               0.643419
# 2021 Q1                2856090.0            26570.0               0.939029
#      Q2                3142970.0           -30420.0              -0.958596
#      Q3                3072630.0           -19160.0              -0.619706
#      Q4                2856620.0           -19150.0              -0.665909
# 2022 Q1                2911880.0            -9710.0              -0.332353
#      Q2                3228590.0                NaN                    NaN

# %%
fig, ax = plt.subplots(figsize=(16,15))
plt.title('US data: differences between computed colonies at the end of the quarter and beginning inventory of next quarter')
plt.ylabel('Difference values (%)')
df_US_new["diff_without_reno_pct"].plot(ax=ax, marker="o",color=custom_states)
plt.axhline(y=0, color='b', linestyle='-')
plt.axhline(y=2.5, color='r', linestyle='-')
plt.axhline(y=-2.5, color='r', linestyle='-')
plt.ylim([-10,+11])
# Out:
# (-10.0, 11.0)

# %% [markdown]
# **!!!!   Coherent results for US    !!!!!** <br>

# %% [markdown]
# ## For each State:

# %%
df_new.head()
# Out:
#                          colony_n  colony_max  colony_lost  colony_lost_pct  \
# year months state
# 2015 Q1     alabama        7000.0      7000.0       1800.0               26
#             arizona       35000.0     35000.0       4600.0               13
#             arkansas      13000.0     14000.0       1500.0               11
#             california  1440000.0   1690000.0     255000.0               15
#             colorado       3500.0     12500.0       1500.0               12
#
#                         colony_added  colony_reno  colony_reno_pct  \
# year months state
# 2015 Q1     alabama             2800        250.0                4
#             arizona             3400       2100.0                6
#             arkansas            1200         90.0                1
#             california        250000     124000.0                7
#             colorado             200        140.0                1
#
#                         Varroa mites  Other pests/parasites  Disesases  \
# year months state
# 2015 Q1     alabama             10.0                    5.4        0.0
#             arizona             26.9                   20.5        0.1
#             arkansas            17.6                   11.4        1.5
#             california          24.7                    7.2        3.0
#             colorado            14.6                    0.9        1.8
#
#                         Pesticides  Other  Unknown
# year months state
# 2015 Q1     alabama            2.2    9.1      9.4
#             arizona            0.0    1.8      3.1
#             arkansas           3.4    1.0      1.0
#             california         7.5    6.5      2.8
#             colorado           0.6    2.6      5.9

# %%
#at time t: n_colony(t) = max_colony(t-1)+colony_added(t-1)- colony_lost(t-1)

df_new_states = df_new.reset_index().groupby(["state", "year", "months"]).sum()
df_new_states["colony_end"] = df_new_states["colony_n"].shift(-1) #number of colonies at the beginning of next trimester
#number of colonies we would expect to have at the end of the trimester:
df_new_states["colony_end_computed"] = df_new_states["colony_max"] + df_new_states["colony_added"] - df_new_states["colony_lost"]
df_new_states["diff"] = df_new_states["colony_end_computed"] - df_new_states["colony_end"] #differences between expected
#number of colonies and real number at the end of the trimester
df_new_states["diff_pct"] = df_new_states["diff"]*100/df_new_states["colony_max"]


#Let's set "differences" and "problem_check" equal to 0 in 2019-Q1 since the values for 2019-Q2 are missing so
#these two features cannot be properly computed
df_new_states.loc[(slice(None), 2019, "Q1"),["diff", "diff_pct"]] = 0

#Let's also set "differences" and "problem_check" equal to 0 in 2022-Q2 since these values compare
#"colony_end_computed" with "colony_end" at 2015-Q1 of another state --> this does not have sense
df_new_states.loc[(slice(None), 2022, "Q2"),["diff", "diff_pct"]] = 0

#the differences which is encoded in "diff_pct" are critical when they are < 0. Indeed, if our data knowledge is
#correct, we would expect to have "colony_end_computed" > "colony_end" since there are no information of the colonies
#that left the state during the trimester.
#If this is not the case (i.e. "diff_pct" < 0), it means that there are some issues in our understanding
#of datapoints and how we are trying to link them along the trimesters.
pd.Series(df_new_states["diff_pct"] < 0).value_counts()
#df_states.head(50)

#Note that "diff" and "diff_pct" do not account for "colony_repo" (as if these were not colony added during the trimester),
# Out:
# False    1006
# True      328
# Name: diff_pct, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(16,15))
plt.title('Differences between computed colony (without colony_repo) and the given one at the end of the trimester')
plt.ylabel('Difference percentage (%)')
df_new_states["diff_pct"].unstack(level=0).plot(ax=ax,color=custom_states)
plt.axhline(y=0, color='r', linestyle='-')
plt.axhline(y=5, color='r', linestyle='-')
plt.axhline(y=-5, color='r', linestyle='-')

# Shrink current axis by 10%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# ## WOOOOOOOWWWWW FINALLY !!!!

# %%
#critical states, years and quarters where the data are not that coherent
df_new_states[df_new_states["diff_pct"] < -5]["diff_pct"]
#df_new_states.loc[("connecticut", slice(None), slice(None)),:]
# Out:
# state          year  months
# alabama        2016  Q4        -8.000000
#                2017  Q1        -7.571429
#                      Q4        -5.866667
# arizona        2016  Q4        -6.129032
# arkansas       2017  Q4        -8.000000
#                2018  Q2       -12.500000
#                      Q4        -9.322581
# colorado       2015  Q1        -6.400000
# connecticut    2016  Q2       -12.400000
#                      Q4        -7.741935
#                2017  Q1        -5.806452
#                      Q3       -16.571429
#                2018  Q1       -21.379310
#                      Q3       -10.937500
# florida        2015  Q4        -8.461538
# georgia        2016  Q4        -8.928571
# hawaii         2017  Q4        -7.733333
# illinois       2015  Q1        -8.571429
#                2016  Q2        -6.000000
#                      Q4       -30.222222
#                2017  Q3        -6.846154
#                2018  Q1        -8.571429
#                      Q3        -8.727273
# indiana        2016  Q4        -9.066667
#                2018  Q1        -8.750000
# iowa           2018  Q1        -6.431818
# kansas         2018  Q1       -21.081081
# kentucky       2015  Q1        -8.095238
#                2018  Q1        -8.000000
#                      Q3        -7.714286
# maine          2018  Q1       -36.315789
# massachusetts  2015  Q1        -5.217391
#                2016  Q1       -12.333333
#                2017  Q1       -17.575758
#                2018  Q1       -15.135135
# michigan       2018  Q1        -8.108108
# mississippi    2016  Q4       -10.233333
#                2018  Q4       -10.680000
# missouri       2017  Q2        -6.714286
#                      Q3        -8.444444
#                2018  Q2       -18.428571
# nebraska       2018  Q2        -8.913043
# new jersey     2018  Q3       -11.214286
# new york       2018  Q2       -11.190476
# ohio           2017  Q2       -14.000000
#                2018  Q1        -8.571429
# oklahoma       2015  Q1        -9.230769
#                      Q4       -38.600000
#                2018  Q3       -21.428571
# other states   2015  Q1        -9.121246
#                2016  Q1       -10.957179
#                2017  Q1        -8.782743
# pennsylvania   2016  Q1        -7.360000
#                2017  Q3        -5.405405
#                2018  Q1       -17.333333
# tennessee      2016  Q1        -5.777778
#                2017  Q4        -5.428571
#                2018  Q1        -8.600000
# texas          2017  Q3        -5.217391
# vermont        2018  Q1       -14.363636
# virginia       2016  Q4       -21.428571
# west virginia  2016  Q1        -8.750000
#                2018  Q1        -7.882353
# wyoming        2018  Q2        -6.428571
# Name: diff_pct, dtype: float64
